# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 5GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/msmarco-docs-data/msmarco-docs.tsv
# /kaggle/input/msmarcotop100/msmarco-doctrain-top100
# /kaggle/input/compiledlucene/bk/Makefile
# /kaggle/input/compiledlucene/bk/dist/lucene-8.1.1-py3.6-linux-x86_64.egg
# /kaggle/input/compiledlucene/bk/JCC-3.7-py3.6-linux-x86_64.egg/libjcc3.so
# /kaggle/input/compiledlucene/bk/JCC-3.7-py3.6-linux-x86_64.egg/jcc/_jcc3.py
# /kaggle/input/compiledlucene/bk/JCC-3.7-py3.6-linux-x86_64.egg/jcc/python.py
# /kaggle/input/compiledlucene/bk/JCC-3.7-py3.6-linux-x86_64.egg/jcc/__init__.py
# /kaggle/input/compiledlucene/bk/JCC-3.7-py3.6-linux-x86_64.egg/jcc/_jcc3.cpython-36m-x86_64-linux-gnu.so
# /kaggle/input/compiledlucene/bk/JCC-3.7-py3.6-linux-x86_64.egg/jcc/cpp.py
# /kaggle/input/compiledlucene/bk/JCC-3.7-py3.6-linux-x86_64.egg/jcc/__main__.py
# /kaggle/input/compiledlucene/bk/JCC-3.7-py3.6-linux-x86_64.egg/jcc/config.py
# /kaggle/input/compiledlucene/bk/JCC-3.7-py3.6-linux-x86_64.egg/jcc/windows.py
# /kaggle/input/compiledlucene/bk/JCC-3.7-py3.6-linux-x86_64.egg/jcc/classes/org/apache/jcc/PythonException.class
# /kaggle/input/compiledlucene/bk/JCC-3.7-py3.6-linux-x86_64.egg/jcc/classes/org/apache/jcc/PythonVM.class
# /kaggle/input/compiledlucene/bk/JCC-3.7-py3.6-linux-x86_64.egg/jcc/sources/JArray.h
# /kaggle/input/compiledlucene/bk/JCC-3.7-py3.6-linux-x86_64.egg/jcc/sources/JArray.cpp
# /kaggle/input/compiledlucene/bk/JCC-3.7-py3.6-linux-x86_64.egg/jcc/sources/types.cpp
# /kaggle/input/compiledlucene/bk/JCC-3.7-py3.6-linux-x86_64.egg/jcc/sources/JObject.cpp
# /kaggle/input/compiledlucene/bk/JCC-3.7-py3.6-linux-x86_64.egg/jcc/sources/JCCEnv.cpp
# /kaggle/input/compiledlucene/bk/JCC-3.7-py3.6-linux-x86_64.egg/jcc/sources/functions.cpp
# /kaggle/input/compiledlucene/bk/JCC-3.7-py3.6-linux-x86_64.egg/jcc/sources/functions.h
# /kaggle/input/compiledlucene/bk/JCC-3.7-py3.6-linux-x86_64.egg/jcc/sources/JCCEnv.h
# /kaggle/input/compiledlucene/bk/JCC-3.7-py3.6-linux-x86_64.egg/jcc/sources/jcc.cpp
# /kaggle/input/compiledlucene/bk/JCC-3.7-py3.6-linux-x86_64.egg/jcc/sources/macros.h
# /kaggle/input/compiledlucene/bk/JCC-3.7-py3.6-linux-x86_64.egg/jcc/sources/jccfuncs.h
# /kaggle/input/compiledlucene/bk/JCC-3.7-py3.6-linux-x86_64.egg/jcc/sources/JObject.h
# /kaggle/input/compiledlucene/bk/JCC-3.7-py3.6-linux-x86_64.egg/EGG-INFO/not-zip-safe
# /kaggle/input/compiledlucene/bk/JCC-3.7-py3.6-linux-x86_64.egg/EGG-INFO/PKG-INFO
# /kaggle/input/compiledlucene/bk/JCC-3.7-py3.6-linux-x86_64.egg/EGG-INFO/native_libs.txt
# /kaggle/input/compiledlucene/bk/JCC-3.7-py3.6-linux-x86_64.egg/EGG-INFO/dependency_links.txt
# /kaggle/input/compiledlucene/bk/JCC-3.7-py3.6-linux-x86_64.egg/EGG-INFO/top_level.txt
# /kaggle/input/compiledlucene/bk/JCC-3.7-py3.6-linux-x86_64.egg/EGG-INFO/SOURCES.txt
# /kaggle/input/compiledlucene/bk/lucene-8.1.1-py3.6-linux-x86_64.egg/EGG-INFO/not-zip-safe
# /kaggle/input/compiledlucene/bk/lucene-8.1.1-py3.6-linux-x86_64.egg/EGG-INFO/PKG-INFO
# /kaggle/input/compiledlucene/bk/lucene-8.1.1-py3.6-linux-x86_64.egg/EGG-INFO/native_libs.txt
# /kaggle/input/compiledlucene/bk/lucene-8.1.1-py3.6-linux-x86_64.egg/EGG-INFO/dependency_links.txt
# /kaggle/input/compiledlucene/bk/lucene-8.1.1-py3.6-linux-x86_64.egg/EGG-INFO/top_level.txt
# /kaggle/input/compiledlucene/bk/lucene-8.1.1-py3.6-linux-x86_64.egg/EGG-INFO/SOURCES.txt
# /kaggle/input/compiledlucene/bk/lucene-8.1.1-py3.6-linux-x86_64.egg/lucene/antlr4-runtime-4.5.1-1.jar
# /kaggle/input/compiledlucene/bk/lucene-8.1.1-py3.6-linux-x86_64.egg/lucene/hppc-0.8.1.jar
# /kaggle/input/compiledlucene/bk/lucene-8.1.1-py3.6-linux-x86_64.egg/lucene/lucene-analyzers-stempel-8.1.1.jar
# /kaggle/input/compiledlucene/bk/lucene-8.1.1-py3.6-linux-x86_64.egg/lucene/lucene-analyzers-kuromoji-8.1.1.jar
# /kaggle/input/compiledlucene/bk/lucene-8.1.1-py3.6-linux-x86_64.egg/lucene/lucene-analyzers-nori-8.1.1.jar
# /kaggle/input/compiledlucene/bk/lucene-8.1.1-py3.6-linux-x86_64.egg/lucene/asm-commons-5.1.jar
# /kaggle/input/compiledlucene/bk/lucene-8.1.1-py3.6-linux-x86_64.egg/lucene/ICUNormalizer2Filter.py
# /kaggle/input/compiledlucene/bk/lucene-8.1.1-py3.6-linux-x86_64.egg/lucene/collections.py
# /kaggle/input/compiledlucene/bk/lucene-8.1.1-py3.6-linux-x86_64.egg/lucene/extensions.jar
# /kaggle/input/compiledlucene/bk/lucene-8.1.1-py3.6-linux-x86_64.egg/lucene/lucene-spatial3d-8.1.1.jar
# /kaggle/input/compiledlucene/bk/lucene-8.1.1-py3.6-linux-x86_64.egg/lucene/lucene-join-8.1.1.jar
# /kaggle/input/compiledlucene/bk/lucene-8.1.1-py3.6-linux-x86_64.egg/lucene/lucene-suggest-8.1.1.jar
# /kaggle/input/compiledlucene/bk/lucene-8.1.1-py3.6-linux-x86_64.egg/lucene/lucene-highlighter-8.1.1.jar
# /kaggle/input/compiledlucene/bk/lucene-8.1.1-py3.6-linux-x86_64.egg/lucene/lucene-analyzers-common-8.1.1.jar
# /kaggle/input/compiledlucene/bk/lucene-8.1.1-py3.6-linux-x86_64.egg/lucene/_lucene.py
# /kaggle/input/compiledlucene/bk/lucene-8.1.1-py3.6-linux-x86_64.egg/lucene/_lucene.cpython-36m-x86_64-linux-gnu.so
# /kaggle/input/compiledlucene/bk/lucene-8.1.1-py3.6-linux-x86_64.egg/lucene/lucene-backward-codecs-8.1.1.jar
# /kaggle/input/compiledlucene/bk/lucene-8.1.1-py3.6-linux-x86_64.egg/lucene/lucene-sandbox-8.1.1.jar
# /kaggle/input/compiledlucene/bk/lucene-8.1.1-py3.6-linux-x86_64.egg/lucene/lucene-expressions-8.1.1.jar
# /kaggle/input/compiledlucene/bk/lucene-8.1.1-py3.6-linux-x86_64.egg/lucene/__init__.py
# /kaggle/input/compiledlucene/bk/lucene-8.1.1-py3.6-linux-x86_64.egg/lucene/lucene-spatial-8.1.1.jar
# /kaggle/input/compiledlucene/bk/lucene-8.1.1-py3.6-linux-x86_64.egg/lucene/lucene-grouping-8.1.1.jar
# /kaggle/input/compiledlucene/bk/lucene-8.1.1-py3.6-linux-x86_64.egg/lucene/lucene-queries-8.1.1.jar
# /kaggle/input/compiledlucene/bk/lucene-8.1.1-py3.6-linux-x86_64.egg/lucene/lucene-core-8.1.1.jar
# /kaggle/input/compiledlucene/bk/lucene-8.1.1-py3.6-linux-x86_64.egg/lucene/lucene-memory-8.1.1.jar
# /kaggle/input/compiledlucene/bk/lucene-8.1.1-py3.6-linux-x86_64.egg/lucene/lucene-facet-8.1.1.jar
# /kaggle/input/compiledlucene/bk/lucene-8.1.1-py3.6-linux-x86_64.egg/lucene/ICUFoldingFilter.py
# /kaggle/input/compiledlucene/bk/lucene-8.1.1-py3.6-linux-x86_64.egg/lucene/asm-5.1.jar
# /kaggle/input/compiledlucene/bk/lucene-8.1.1-py3.6-linux-x86_64.egg/lucene/lucene-classification-8.1.1.jar
# /kaggle/input/compiledlucene/bk/lucene-8.1.1-py3.6-linux-x86_64.egg/lucene/lucene-queryparser-8.1.1.jar
# /kaggle/input/compiledlucene/bk/lucene-8.1.1-py3.6-linux-x86_64.egg/lucene/lucene-codecs-8.1.1.jar
# /kaggle/input/compiledlucene/bk/lucene-8.1.1-py3.6-linux-x86_64.egg/lucene/lucene-misc-8.1.1.jar
# /kaggle/input/compiledlucene/bk/lucene-8.1.1-py3.6-linux-x86_64.egg/lucene/ICUTransformFilter.py
# /kaggle/input/compiledlucene/bk/build/temp.linux-x86_64-3.6/build/_lucene/JCCEnv.o
# /kaggle/input/compiledlucene/bk/build/temp.linux-x86_64-3.6/build/_lucene/__wrap01__.o
# /kaggle/input/compiledlucene/bk/build/temp.linux-x86_64-3.6/build/_lucene/__wrap02__.o
# /kaggle/input/compiledlucene/bk/build/temp.linux-x86_64-3.6/build/_lucene/__wrap06__.o
# /kaggle/input/compiledlucene/bk/build/temp.linux-x86_64-3.6/build/_lucene/types.o
# /kaggle/input/compiledlucene/bk/build/temp.linux-x86_64-3.6/build/_lucene/__wrap10__.o
# /kaggle/input/compiledlucene/bk/build/temp.linux-x86_64-3.6/build/_lucene/__wrap11__.o
# /kaggle/input/compiledlucene/bk/build/temp.linux-x86_64-3.6/build/_lucene/__wrap03__.o
# /kaggle/input/compiledlucene/bk/build/temp.linux-x86_64-3.6/build/_lucene/__wrap05__.o
# /kaggle/input/compiledlucene/bk/build/temp.linux-x86_64-3.6/build/_lucene/__wrap07__.o
# /kaggle/input/compiledlucene/bk/build/temp.linux-x86_64-3.6/build/_lucene/JArray.o
# /kaggle/input/compiledlucene/bk/build/temp.linux-x86_64-3.6/build/_lucene/__init__.o
# /kaggle/input/compiledlucene/bk/build/temp.linux-x86_64-3.6/build/_lucene/lucene.o
# /kaggle/input/compiledlucene/bk/build/temp.linux-x86_64-3.6/build/_lucene/__wrap04__.o
# /kaggle/input/compiledlucene/bk/build/temp.linux-x86_64-3.6/build/_lucene/jcc.o
# /kaggle/input/compiledlucene/bk/build/temp.linux-x86_64-3.6/build/_lucene/__wrap08__.o
# /kaggle/input/compiledlucene/bk/build/temp.linux-x86_64-3.6/build/_lucene/__wrap09__.o
# /kaggle/input/compiledlucene/bk/build/temp.linux-x86_64-3.6/build/_lucene/JObject.o
# /kaggle/input/compiledlucene/bk/build/temp.linux-x86_64-3.6/build/_lucene/functions.o
# /kaggle/input/compiledlucene/bk/build/jar/extensions.jar
# /kaggle/input/compiledlucene/bk/build/_lucene/__wrap02__.cpp
# /kaggle/input/compiledlucene/bk/build/_lucene/JArray.cpp
# /kaggle/input/compiledlucene/bk/build/_lucene/lucene.cpp
# /kaggle/input/compiledlucene/bk/build/_lucene/__wrap08__.cpp
# /kaggle/input/compiledlucene/bk/build/_lucene/types.cpp
# /kaggle/input/compiledlucene/bk/build/_lucene/__wrap06__.cpp
# /kaggle/input/compiledlucene/bk/build/_lucene/JObject.cpp
# /kaggle/input/compiledlucene/bk/build/_lucene/JCCEnv.cpp
# /kaggle/input/compiledlucene/bk/build/_lucene/__wrap07__.cpp
# /kaggle/input/compiledlucene/bk/build/_lucene/__wrap11__.cpp
# /kaggle/input/compiledlucene/bk/build/_lucene/functions.cpp
# /kaggle/input/compiledlucene/bk/build/_lucene/__wrap03__.cpp
# /kaggle/input/compiledlucene/bk/build/_lucene/__wrap04__.cpp
# /kaggle/input/compiledlucene/bk/build/_lucene/__wrap09__.cpp
# /kaggle/input/compiledlucene/bk/build/_lucene/__wrap05__.cpp
# /kaggle/input/compiledlucene/bk/build/_lucene/jcc.cpp
# /kaggle/input/compiledlucene/bk/build/_lucene/__wrap01__.cpp
# /kaggle/input/compiledlucene/bk/build/_lucene/__init__.cpp
# /kaggle/input/compiledlucene/bk/build/_lucene/__wrap10__.cpp
# /kaggle/input/compiledlucene/bk/build/_lucene/java/nio/file/PathMatcher.h
# /kaggle/input/compiledlucene/bk/build/_lucene/java/nio/file/LinkOption.h
# /kaggle/input/compiledlucene/bk/build/_lucene/java/nio/file/Path.h
# /kaggle/input/compiledlucene/bk/build/_lucene/java/nio/file/Paths.h
# /kaggle/input/compiledlucene/bk/build/_lucene/java/nio/file/WatchService.h
# /kaggle/input/compiledlucene/bk/build/_lucene/java/nio/file/DirectoryStream.h
# /kaggle/input/compiledlucene/bk/build/_lucene/java/nio/file/Watchable.h
# /kaggle/input/compiledlucene/bk/build/_lucene/java/nio/file/FileVisitOption.h
# /kaggle/input/compiledlucene/bk/build/_lucene/java/nio/file/Files.h
# /kaggle/input/compiledlucene/bk/build/_lucene/java/nio/file/DirectoryStream$Filter.h
# /kaggle/input/compiledlucene/bk/build/_lucene/java/nio/file/FileVisitResult.h
# /kaggle/input/compiledlucene/bk/build/_lucene/java/nio/file/FileVisitor.h
# /kaggle/input/compiledlucene/bk/build/_lucene/java/nio/file/WatchKey.h
# /kaggle/input/compiledlucene/bk/build/_lucene/java/nio/file/OpenOption.h
# /kaggle/input/compiledlucene/bk/build/_lucene/java/nio/file/WatchEvent.h
# /kaggle/input/compiledlucene/bk/build/_lucene/java/nio/file/WatchEvent$Modifier.h
# /kaggle/input/compiledlucene/bk/build/_lucene/java/nio/file/CopyOption.h
# /kaggle/input/compiledlucene/bk/build/_lucene/java/nio/file/WatchEvent$Kind.h
# /kaggle/input/compiledlucene/bk/build/_lucene/java/nio/file/FileStore.h
# /kaggle/input/compiledlucene/bk/build/_lucene/java/nio/file/FileSystem.h
# /kaggle/input/compiledlucene/bk/build/_lucene/java/io/Serializable.h
# /kaggle/input/compiledlucene/bk/build/_lucene/java/io/File.h
# /kaggle/input/compiledlucene/bk/build/_lucene/java/io/EOFException.h
# /kaggle/input/compiledlucene/bk/build/_lucene/java/io/Flushable.h
# /kaggle/input/compiledlucene/bk/build/_lucene/java/io/BufferedReader.h
# /kaggle/input/compiledlucene/bk/build/_lucene/java/io/Console.h
# /kaggle/input/compiledlucene/bk/build/_lucene/java/io/SyncFailedException.h
# /kaggle/input/compiledlucene/bk/build/_lucene/java/io/OutputStream.h
# /kaggle/input/compiledlucene/bk/build/_lucene/java/io/FilenameFilter.h
# /kaggle/input/compiledlucene/bk/build/_lucene/java/io/StringReader.h
# /kaggle/input/compiledlucene/bk/build/_lucene/java/io/DataInput.h
# /kaggle/input/compiledlucene/bk/build/_lucene/java/io/DataOutput.h
# /kaggle/input/compiledlucene/bk/build/_lucene/java/io/FileFilter.h
# /kaggle/input/compiledlucene/bk/build/_lucene/java/io/PrintStream.h
# /kaggle/input/compiledlucene/bk/build/_lucene/java/io/Writer.h
# /kaggle/input/compiledlucene/bk/build/_lucene/java/io/Reader.h
# /kaggle/input/compiledlucene/bk/build/_lucene/java/io/IOException.h
# /kaggle/input/compiledlucene/bk/build/_lucene/java/io/Closeable.h
# /kaggle/input/compiledlucene/bk/build/_lucene/java/io/InputStream.h
# /kaggle/input/compiledlucene/bk/build/_lucene/java/io/UnsupportedEncodingException.h
# /kaggle/input/compiledlucene/bk/build/_lucene/java/io/FilterOutputStream.h
# /kaggle/input/compiledlucene/bk/build/_lucene/java/io/StringWriter.h
# /kaggle/input/compiledlucene/bk/build/_lucene/java/io/PrintWriter.h
# /kaggle/input/compiledlucene/bk/build/_lucene/java/io/FileDescriptor.h
# /kaggle/input/compiledlucene/bk/build/_lucene/java/io/BufferedWriter.h
# /kaggle/input/compiledlucene/bk/build/_lucene/java/io/FileNotFoundException.h
# /kaggle/input/compiledlucene/bk/build/_lucene/java/text/DecimalFormat.h
# /kaggle/input/compiledlucene/bk/build/_lucene/java/text/SimpleDateFormat.h
# /kaggle/input/compiledlucene/bk/build/_lucene/java/text/BreakIterator.h
# /kaggle/input/compiledlucene/bk/build/_lucene/java/text/NumberFormat.h
# /kaggle/input/compiledlucene/bk/build/_lucene/java/text/Format.h
# /kaggle/input/compiledlucene/bk/build/_lucene/java/text/Collator.h
# /kaggle/input/compiledlucene/bk/build/_lucene/java/text/DateFormat.h
# /kaggle/input/compiledlucene/bk/build/_lucene/java/util/AbstractList.h
# /kaggle/input/compiledlucene/bk/build/_lucene/java/util/Locale.h
# /kaggle/input/compiledlucene/bk/build/_lucene/java/util/Random.h
# /kaggle/input/compiledlucene/bk/build/_lucene/java/util/AbstractCollection.h
# /kaggle/input/compiledlucene/bk/build/_lucene/java/util/Deque.h
# /kaggle/input/compiledlucene/bk/build/_lucene/java/util/SortedMap.h
# /kaggle/input/compiledlucene/bk/build/_lucene/java/util/Spliterator.h
# /kaggle/input/compiledlucene/bk/build/_lucene/java/util/UUID.h
# /kaggle/input/compiledlucene/bk/build/_lucene/java/util/Iterator.h
# /kaggle/input/compiledlucene/bk/build/_lucene/java/util/NoSuchElementException.h
# /kaggle/input/compiledlucene/bk/build/_lucene/java/util/List.h
# /kaggle/input/compiledlucene/bk/build/_lucene/java/util/Collection.h
# /kaggle/input/compiledlucene/bk/build/_lucene/java/util/ArrayList.h
# /kaggle/input/compiledlucene/bk/build/_lucene/java/util/AbstractSet.h
# /kaggle/input/compiledlucene/bk/build/_lucene/java/util/Spliterator$OfDouble.h
# /kaggle/input/compiledlucene/bk/build/_lucene/java/util/Set.h
# /kaggle/input/compiledlucene/bk/build/_lucene/java/util/Properties.h
# /kaggle/input/compiledlucene/bk/build/_lucene/java/util/Arrays.h
# /kaggle/input/compiledlucene/bk/build/_lucene/java/util/Spliterator$OfLong.h
# /kaggle/input/compiledlucene/bk/build/_lucene/java/util/Locale$Category.h
# /kaggle/input/compiledlucene/bk/build/_lucene/java/util/Comparator.h
# /kaggle/input/compiledlucene/bk/build/_lucene/java/util/InvalidPropertiesFormatException.h
# /kaggle/input/compiledlucene/bk/build/_lucene/java/util/Locale$FilteringMode.h
# /kaggle/input/compiledlucene/bk/build/_lucene/java/util/HashSet.h
# /kaggle/input/compiledlucene/bk/build/_lucene/java/util/TreeSet.h
# /kaggle/input/compiledlucene/bk/build/_lucene/java/util/MissingResourceException.h
# /kaggle/input/compiledlucene/bk/build/_lucene/java/util/Enumeration.h
# /kaggle/input/compiledlucene/bk/build/_lucene/java/util/Map.h
# /kaggle/input/compiledlucene/bk/build/_lucene/java/util/Date.h
# /kaggle/input/compiledlucene/bk/build/_lucene/java/util/BitSet.h
# /kaggle/input/compiledlucene/bk/build/_lucene/java/util/LinkedList.h
# /kaggle/input/compiledlucene/bk/build/_lucene/java/util/Calendar.h
# /kaggle/input/compiledlucene/bk/build/_lucene/java/util/Queue.h
# /kaggle/input/compiledlucene/bk/build/_lucene/java/util/SortedSet.h
# /kaggle/input/compiledlucene/bk/build/_lucene/java/util/RandomAccess.h
# /kaggle/input/compiledlucene/bk/build/_lucene/java/util/Currency.h
# /kaggle/input/compiledlucene/bk/build/_lucene/java/util/AbstractMap.h
# /kaggle/input/compiledlucene/bk/build/_lucene/java/util/NavigableMap.h
# /kaggle/input/compiledlucene/bk/build/_lucene/java/util/ListIterator.h
# /kaggle/input/compiledlucene/bk/build/_lucene/java/util/Dictionary.h
# /kaggle/input/compiledlucene/bk/build/_lucene/java/util/Spliterator$OfPrimitive.h
# /kaggle/input/compiledlucene/bk/build/_lucene/java/util/LinkedHashMap.h
# /kaggle/input/compiledlucene/bk/build/_lucene/java/util/Spliterator$OfInt.h
# /kaggle/input/compiledlucene/bk/build/_lucene/java/util/AbstractSequentialList.h
# /kaggle/input/compiledlucene/bk/build/_lucene/java/util/Collections.h
# /kaggle/input/compiledlucene/bk/build/_lucene/java/util/TimeZone.h
# /kaggle/input/compiledlucene/bk/build/_lucene/java/util/Map$Entry.h
# /kaggle/input/compiledlucene/bk/build/_lucene/java/util/HashMap.h
# /kaggle/input/compiledlucene/bk/build/_lucene/java/util/Locale$LanguageRange.h
# /kaggle/input/compiledlucene/bk/build/_lucene/java/util/Hashtable.h
# /kaggle/input/compiledlucene/bk/build/_lucene/java/util/NavigableSet.h
# /kaggle/input/compiledlucene/bk/build/_lucene/java/util/regex/MatchResult.h
# /kaggle/input/compiledlucene/bk/build/_lucene/java/util/regex/Matcher.h
# /kaggle/input/compiledlucene/bk/build/_lucene/java/util/regex/Pattern.h
# /kaggle/input/compiledlucene/bk/build/_lucene/java/util/concurrent/ExecutorService.h
# /kaggle/input/compiledlucene/bk/build/_lucene/java/util/concurrent/ThreadFactory.h
# /kaggle/input/compiledlucene/bk/build/_lucene/java/util/concurrent/AbstractExecutorService.h
# /kaggle/input/compiledlucene/bk/build/_lucene/java/util/concurrent/Executors.h
# /kaggle/input/compiledlucene/bk/build/_lucene/java/util/concurrent/ScheduledFuture.h
# /kaggle/input/compiledlucene/bk/build/_lucene/java/util/concurrent/TimeUnit.h
# /kaggle/input/compiledlucene/bk/build/_lucene/java/util/concurrent/TimeoutException.h
# /kaggle/input/compiledlucene/bk/build/_lucene/java/util/concurrent/ScheduledExecutorService.h
# /kaggle/input/compiledlucene/bk/build/_lucene/java/util/concurrent/Future.h
# /kaggle/input/compiledlucene/bk/build/_lucene/java/util/concurrent/Callable.h
# /kaggle/input/compiledlucene/bk/build/_lucene/java/util/concurrent/Delayed.h
# /kaggle/input/compiledlucene/bk/build/_lucene/java/util/concurrent/Executor.h
# /kaggle/input/compiledlucene/bk/build/_lucene/java/util/concurrent/ExecutionException.h
# /kaggle/input/compiledlucene/bk/build/_lucene/java/util/function/LongConsumer.h
# /kaggle/input/compiledlucene/bk/build/_lucene/java/util/function/IntConsumer.h
# /kaggle/input/compiledlucene/bk/build/_lucene/java/util/function/DoubleConsumer.h
# /kaggle/input/compiledlucene/bk/build/_lucene/java/lang/IllegalStateException.h
# /kaggle/input/compiledlucene/bk/build/_lucene/java/lang/Thread$UncaughtExceptionHandler.h
# /kaggle/input/compiledlucene/bk/build/_lucene/java/lang/Byte.h
# /kaggle/input/compiledlucene/bk/build/_lucene/java/lang/Thread$State.h
# /kaggle/input/compiledlucene/bk/build/_lucene/java/lang/Runnable.h
# /kaggle/input/compiledlucene/bk/build/_lucene/java/lang/IllegalAccessException.h
# /kaggle/input/compiledlucene/bk/build/_lucene/java/lang/Short.h
# /kaggle/input/compiledlucene/bk/build/_lucene/java/lang/Error.h
# /kaggle/input/compiledlucene/bk/build/_lucene/java/lang/Boolean.h
# /kaggle/input/compiledlucene/bk/build/_lucene/java/lang/Throwable.h
# /kaggle/input/compiledlucene/bk/build/_lucene/java/lang/Exception.h
# /kaggle/input/compiledlucene/bk/build/_lucene/java/lang/SecurityException.h
# /kaggle/input/compiledlucene/bk/build/_lucene/java/lang/Runtime.h
# /kaggle/input/compiledlucene/bk/build/_lucene/java/lang/Readable.h
# /kaggle/input/compiledlucene/bk/build/_lucene/java/lang/AbstractStringBuilder.h
# /kaggle/input/compiledlucene/bk/build/_lucene/java/lang/CloneNotSupportedException.h
# /kaggle/input/compiledlucene/bk/build/_lucene/java/lang/Iterable.h
# /kaggle/input/compiledlucene/bk/build/_lucene/java/lang/Double.h
# /kaggle/input/compiledlucene/bk/build/_lucene/java/lang/IndexOutOfBoundsException.h
# /kaggle/input/compiledlucene/bk/build/_lucene/java/lang/StringBuilder.h
# /kaggle/input/compiledlucene/bk/build/_lucene/java/lang/AutoCloseable.h
# /kaggle/input/compiledlucene/bk/build/_lucene/java/lang/Float.h
# /kaggle/input/compiledlucene/bk/build/_lucene/java/lang/UnsupportedOperationException.h
# /kaggle/input/compiledlucene/bk/build/_lucene/java/lang/Appendable.h
# /kaggle/input/compiledlucene/bk/build/_lucene/java/lang/ClassLoader.h
# /kaggle/input/compiledlucene/bk/build/_lucene/java/lang/StackTraceElement.h
# /kaggle/input/compiledlucene/bk/build/_lucene/java/lang/Number.h
# /kaggle/input/compiledlucene/bk/build/_lucene/java/lang/Object.h
# /kaggle/input/compiledlucene/bk/build/_lucene/java/lang/Class.h
# /kaggle/input/compiledlucene/bk/build/_lucene/java/lang/StringBuffer.h
# /kaggle/input/compiledlucene/bk/build/_lucene/java/lang/Enum.h
# /kaggle/input/compiledlucene/bk/build/_lucene/java/lang/ReflectiveOperationException.h
# /kaggle/input/compiledlucene/bk/build/_lucene/java/lang/ClassNotFoundException.h
# /kaggle/input/compiledlucene/bk/build/_lucene/java/lang/Process.h
# /kaggle/input/compiledlucene/bk/build/_lucene/java/lang/Long.h
# /kaggle/input/compiledlucene/bk/build/_lucene/java/lang/System.h
# /kaggle/input/compiledlucene/bk/build/_lucene/java/lang/CharSequence.h
# /kaggle/input/compiledlucene/bk/build/_lucene/java/lang/Cloneable.h
# /kaggle/input/compiledlucene/bk/build/_lucene/java/lang/Character.h
# /kaggle/input/compiledlucene/bk/build/_lucene/java/lang/RuntimeException.h
# /kaggle/input/compiledlucene/bk/build/_lucene/java/lang/ThreadGroup.h
# /kaggle/input/compiledlucene/bk/build/_lucene/java/lang/InstantiationException.h
# /kaggle/input/compiledlucene/bk/build/_lucene/java/lang/Package.h
# /kaggle/input/compiledlucene/bk/build/_lucene/java/lang/Thread.h
# /kaggle/input/compiledlucene/bk/build/_lucene/java/lang/Comparable.h
# /kaggle/input/compiledlucene/bk/build/_lucene/java/lang/InterruptedException.h
# /kaggle/input/compiledlucene/bk/build/_lucene/java/lang/NumberFormatException.h
# /kaggle/input/compiledlucene/bk/build/_lucene/java/lang/String.h
# /kaggle/input/compiledlucene/bk/build/_lucene/java/lang/SecurityManager.h
# /kaggle/input/compiledlucene/bk/build/_lucene/java/lang/Integer.h
# /kaggle/input/compiledlucene/bk/build/_lucene/java/lang/IllegalArgumentException.h
# /kaggle/input/compiledlucene/bk/build/_lucene/org/xml/sax/helpers/DefaultHandler.h
# /kaggle/input/compiledlucene/bk/build/_lucene/org/antlr/v4/runtime/RuleContext.h
# /kaggle/input/compiledlucene/bk/build/_lucene/org/antlr/v4/runtime/ParserRuleContext.h
# /kaggle/input/compiledlucene/bk/build/_lucene/org/antlr/v4/runtime/Token.h
# /kaggle/input/compiledlucene/bk/build/_lucene/org/antlr/v4/runtime/atn/ParserATNSimulator.h
# /kaggle/input/compiledlucene/bk/build/_lucene/org/antlr/v4/runtime/atn/ATNSimulator.h
# /kaggle/input/compiledlucene/bk/build/_lucene/org/tartarus/snowball/SnowballProgram.h
# /kaggle/input/compiledlucene/bk/build/_lucene/org/tartarus/snowball/Among.h
# /kaggle/input/compiledlucene/bk/build/_lucene/org/tartarus/snowball/ext/TurkishStemmer.h
# /kaggle/input/compiledlucene/bk/build/_lucene/org/tartarus/snowball/ext/ItalianStemmer.h
# /kaggle/input/compiledlucene/bk/build/_lucene/org/tartarus/snowball/ext/SwedishStemmer.h
# /kaggle/input/compiledlucene/bk/build/_lucene/org/tartarus/snowball/ext/HungarianStemmer.h
# /kaggle/input/compiledlucene/bk/build/_lucene/org/tartarus/snowball/ext/ArabicStemmer.h
# /kaggle/input/compiledlucene/bk/build/_lucene/org/tartarus/snowball/ext/FrenchStemmer.h
# /kaggle/input/compiledlucene/bk/build/_lucene/org/tartarus/snowball/ext/NorwegianStemmer.h
# /kaggle/input/compiledlucene/bk/build/_lucene/org/tartarus/snowball/ext/BasqueStemmer.h
# /kaggle/input/compiledlucene/bk/build/_lucene/org/tartarus/snowball/ext/EnglishStemmer.h
# /kaggle/input/compiledlucene/bk/build/_lucene/org/tartarus/snowball/ext/RomanianStemmer.h
# /kaggle/input/compiledlucene/bk/build/_lucene/org/tartarus/snowball/ext/ArmenianStemmer.h
# /kaggle/input/compiledlucene/bk/build/_lucene/org/tartarus/snowball/ext/IrishStemmer.h
# /kaggle/input/compiledlucene/bk/build/_lucene/org/tartarus/snowball/ext/PortugueseStemmer.h
# /kaggle/input/compiledlucene/bk/build/_lucene/org/tartarus/snowball/ext/CatalanStemmer.h
# /kaggle/input/compiledlucene/bk/build/_lucene/org/tartarus/snowball/ext/German2Stemmer.h
# /kaggle/input/compiledlucene/bk/build/_lucene/org/tartarus/snowball/ext/DutchStemmer.h
# /kaggle/input/compiledlucene/bk/build/_lucene/org/tartarus/snowball/ext/LithuanianStemmer.h
# /kaggle/input/compiledlucene/bk/build/_lucene/org/tartarus/snowball/ext/FinnishStemmer.h
# /kaggle/input/compiledlucene/bk/build/_lucene/org/tartarus/snowball/ext/GermanStemmer.h
# /kaggle/input/compiledlucene/bk/build/_lucene/org/tartarus/snowball/ext/SpanishStemmer.h
# /kaggle/input/compiledlucene/bk/build/_lucene/org/tartarus/snowball/ext/PorterStemmer.h
# /kaggle/input/compiledlucene/bk/build/_lucene/org/tartarus/snowball/ext/DanishStemmer.h
# /kaggle/input/compiledlucene/bk/build/_lucene/org/tartarus/snowball/ext/RussianStemmer.h
# /kaggle/input/compiledlucene/bk/build/_lucene/org/tartarus/snowball/ext/KpStemmer.h
# /kaggle/input/compiledlucene/bk/build/_lucene/org/tartarus/snowball/ext/LovinsStemmer.h
# /kaggle/input/compiledlucene/bk/build/_lucene/org/egothor/stemmer/Row.h
# /kaggle/input/compiledlucene/bk/build/_lucene/org/egothor/stemmer/Optimizer.h
# /kaggle/input/compiledlucene/bk/build/_lucene/org/egothor/stemmer/DiffIt.h
# /kaggle/input/compiledlucene/bk/build/_lucene/org/egothor/stemmer/Lift.h
# /kaggle/input/compiledlucene/bk/build/_lucene/org/egothor/stemmer/MultiTrie2.h
# /kaggle/input/compiledlucene/bk/build/_lucene/org/egothor/stemmer/Gener.h
# /kaggle/input/compiledlucene/bk/build/_lucene/org/egothor/stemmer/Compile.h
# /kaggle/input/compiledlucene/bk/build/_lucene/org/egothor/stemmer/Trie.h
# /kaggle/input/compiledlucene/bk/build/_lucene/org/egothor/stemmer/Optimizer2.h
# /kaggle/input/compiledlucene/bk/build/_lucene/org/egothor/stemmer/MultiTrie.h
# /kaggle/input/compiledlucene/bk/build/_lucene/org/egothor/stemmer/Diff.h
# /kaggle/input/compiledlucene/bk/build/_lucene/org/egothor/stemmer/Reduce.h
# /kaggle/input/compiledlucene/bk/build/_lucene/org/apache/pylucene/search/PythonSimpleCollector.h
# /kaggle/input/compiledlucene/bk/build/_lucene/org/apache/pylucene/search/highlight/PythonFormatter.h
# /kaggle/input/compiledlucene/bk/build/_lucene/org/apache/pylucene/search/highlight/PythonFragmenter.h
# /kaggle/input/compiledlucene/bk/build/_lucene/org/apache/pylucene/search/similarities/PythonClassicSimilarity.h
# /kaggle/input/compiledlucene/bk/build/_lucene/org/apache/pylucene/search/similarities/PythonSimilarity$PythonSimScorer.h
# /kaggle/input/compiledlucene/bk/build/_lucene/org/apache/pylucene/search/similarities/PythonPerFieldSimilarityWrapper.h
# /kaggle/input/compiledlucene/bk/build/_lucene/org/apache/pylucene/search/similarities/PythonSimilarity.h
# /kaggle/input/compiledlucene/bk/build/_lucene/org/apache/pylucene/search/spans/PythonSpanCollector.h
# /kaggle/input/compiledlucene/bk/build/_lucene/org/apache/pylucene/store/PythonLock.h
# /kaggle/input/compiledlucene/bk/build/_lucene/org/apache/pylucene/store/PythonIndexInput.h
# /kaggle/input/compiledlucene/bk/build/_lucene/org/apache/pylucene/store/PythonLockFactory.h
# /kaggle/input/compiledlucene/bk/build/_lucene/org/apache/pylucene/store/PythonIndexOutput.h
# /kaggle/input/compiledlucene/bk/build/_lucene/org/apache/pylucene/store/PythonDirectory.h
# /kaggle/input/compiledlucene/bk/build/_lucene/org/apache/pylucene/analysis/PythonTokenStream.h
# /kaggle/input/compiledlucene/bk/build/_lucene/org/apache/pylucene/analysis/PythonTokenizer.h
# /kaggle/input/compiledlucene/bk/build/_lucene/org/apache/pylucene/analysis/PythonAnalyzer.h
# /kaggle/input/compiledlucene/bk/build/_lucene/org/apache/pylucene/analysis/PythonFilteringTokenFilter.h
# /kaggle/input/compiledlucene/bk/build/_lucene/org/apache/pylucene/analysis/PythonTokenFilter.h
# /kaggle/input/compiledlucene/bk/build/_lucene/org/apache/pylucene/util/PythonSet.h
# /kaggle/input/compiledlucene/bk/build/_lucene/org/apache/pylucene/util/PythonListIterator.h
# /kaggle/input/compiledlucene/bk/build/_lucene/org/apache/pylucene/util/PythonIterator.h
# /kaggle/input/compiledlucene/bk/build/_lucene/org/apache/pylucene/util/PythonList.h
# /kaggle/input/compiledlucene/bk/build/_lucene/org/apache/pylucene/util/PythonAttributeImpl.h
# /kaggle/input/compiledlucene/bk/build/_lucene/org/apache/pylucene/util/PythonComparable.h
# /kaggle/input/compiledlucene/bk/build/_lucene/org/apache/pylucene/util/PythonAttribute.h
# /kaggle/input/compiledlucene/bk/build/_lucene/org/apache/pylucene/index/PythonIndexDeletionPolicy.h
# /kaggle/input/compiledlucene/bk/build/_lucene/org/apache/pylucene/queryparser/classic/PythonMultiFieldQueryParser.h
# /kaggle/input/compiledlucene/bk/build/_lucene/org/apache/pylucene/queryparser/classic/PythonQueryParser.h
# /kaggle/input/compiledlucene/bk/build/_lucene/org/apache/lucene/LucenePackage.h
# /kaggle/input/compiledlucene/bk/build/_lucene/org/apache/lucene/spatial3d/Geo3DDocValuesField.h
# /kaggle/input/compiledlucene/bk/build/_lucene/org/apache/lucene/spatial3d/Geo3DPoint.h
# /kaggle/input/compiledlucene/bk/build/_lucene/org/apache/lucene/spatial3d/geom/GeoPolygon.h
# /kaggle/input/compiledlucene/bk/build/_lucene/org/apache/lucene/spatial3d/geom/GeoOutsideDistance.h
# /kaggle/input/compiledlucene/bk/build/_lucene/org/apache/lucene/spatial3d/geom/GeoCompositeMembershipShape.h
# /kaggle/input/compiledlucene/bk/build/_lucene/org/apache/lucene/spatial3d/geom/GeoArea.h
# /kaggle/input/compiledlucene/bk/build/_lucene/org/apache/lucene/spatial3d/geom/GeoPointShapeFactory.h
# /kaggle/input/compiledlucene/bk/build/_lucene/org/apache/lucene/spatial3d/geom/LinearSquaredDistance.h
# /kaggle/input/compiledlucene/bk/build/_lucene/org/apache/lucene/spatial3d/geom/DistanceStyle.h
# /kaggle/input/compiledlucene/bk/build/_lucene/org/apache/lucene/spatial3d/geom/GeoCompositePolygon.h
# /kaggle/input/compiledlucene/bk/build/_lucene/org/apache/lucene/spatial3d/geom/GeoAreaFactory.h
# /kaggle/input/compiledlucene/bk/build/_lucene/org/apache/lucene/spatial3d/geom/GeoBBoxFactory.h
# /kaggle/input/compiledlucene/bk/build/_lucene/org/apache/lucene/spatial3d/geom/XYZBounds.h
# /kaggle/input/compiledlucene/bk/build/_lucene/org/apache/lucene/spatial3d/geom/GeoBaseCompositeMembershipShape.h
# /kaggle/input/compiledlucene/bk/build/_lucene/org/apache/lucene/spatial3d/geom/LatLonBounds.h
# /kaggle/input/compiledlucene/bk/build/_lucene/org/apache/lucene/spatial3d/geom/GeoPolygonFactory.h
# /kaggle/input/compiledlucene/bk/build/_lucene/org/apache/lucene/spatial3d/geom/GeoDistanceShape.h
# /kaggle/input/compiledlucene/bk/build/_lucene/org/apache/lucene/spatial3d/geom/GeoBaseCompositeShape.h
# /kaggle/input/compiledlucene/bk/build/_lucene/org/apache/lucene/spatial3d/geom/GeoDistance.h
# /kaggle/input/compiledlucene/bk/build/_lucene/org/apache/lucene/spatial3d/geom/GeoPoint.h
# /kaggle/input/compiledlucene/bk/build/_lucene/org/apache/lucene/spatial3d/geom/GeoShape.h
# /kaggle/input/compiledlucene/bk/build/_lucene/org/apache/lucene/spatial3d/geom/GeoDegenerateVerticalLine.h
# /kaggle/input/compiledlucene/bk/build/_lucene/org/apache/lucene/spatial3d/geom/GeoPointShape.h
# /kaggle/input/compiledlucene/bk/build/_lucene/org/apache/lucene/spatial3d/geom/Bounds.h
# /kaggle/input/compiledlucene/bk/build/_lucene/org/apache/lucene/spatial3d/geom/LinearDistance.h
# /kaggle/input/compiledlucene/bk/build/_lucene/org/apache/lucene/spatial3d/geom/Bounded.h
# /kaggle/input/compiledlucene/bk/build/_lucene/org/apache/lucene/spatial3d/geom/PlanetModel.h
# /kaggle/input/compiledlucene/bk/build/_lucene/org/apache/lucene/spatial3d/geom/NormalSquaredDistance.h
# /kaggle/input/compiledlucene/bk/build/_lucene/org/apache/lucene/spatial3d/geom/GeoMembershipShape.h
# /kaggle/input/compiledlucene/bk/build/_lucene/org/apache/lucene/spatial3d/geom/Membership.h
# /kaggle/input/compiledlucene/bk/build/_lucene/org/apache/lucene/spatial3d/geom/GeoCircleFactory.h
# /kaggle/input/compiledlucene/bk/build/_lucene/org/apache/lucene/spatial3d/geom/GeoBaseCompositeAreaShape.h
# /kaggle/input/compiledlucene/bk/build/_lucene/org/apache/lucene/spatial3d/geom/GeoCompositeAreaShape.h
# /kaggle/input/compiledlucene/bk/build/_lucene/org/apache/lucene/spatial3d/geom/NormalDistance.h
# /kaggle/input/compiledlucene/bk/build/_lucene/org/apache/lucene/spatial3d/geom/SerializableObject.h
# /kaggle/input/compiledlucene/bk/build/_lucene/org/apache/lucene/spatial3d/geom/ArcDistance.h
# /kaggle/input/compiledlucene/bk/build/_lucene/org/apache/lucene/spatial3d/geom/XYZSolid.h
# /kaggle/input/compiledlucene/bk/build/_lucene/org/apache/lucene/spatial3d/geom/GeoPath.h
# /kaggle/input/compiledlucene/bk/build/_lucene/org/apache/lucene/spatial3d/geom/GeoBaseDistanceShape.h
# /kaggle/input/compiledlucene/bk/build/_lucene/org/apache/lucene/spatial3d/geom/GeoSizeable.h
# /kaggle/input/compiledlucene/bk/build/_lucene/org/apache/lucene/spatial3d/geom/PlanetObject.h
# /kaggle/input/compiledlucene/bk/build/_lucene/org/apache/lucene/spatial3d/geom/GeoPolygonFactory$PolygonDescription.h
# /kaggle/input/compiledlucene/bk/build/_lucene/org/apache/lucene/spatial3d/geom/GeoBaseShape.h
# /kaggle/input/compiledlucene/bk/build/_lucene/org/apache/lucene/spatial3d/geom/SidedPlane.h
# /kaggle/input/compiledlucene/bk/build/_lucene/org/apache/lucene/spatial3d/geom/Tools.h
# /kaggle/input/compiledlucene/bk/build/_lucene/org/apache/lucene/spatial3d/geom/Plane.h
# /kaggle/input/compiledlucene/bk/build/_lucene/org/apache/lucene/spatial3d/geom/Vector.h
# /kaggle/input/compiledlucene/bk/build/_lucene/org/apache/lucene/spatial3d/geom/GeoBaseBBox.h
# /kaggle/input/compiledlucene/bk/build/_lucene/org/apache/lucene/spatial3d/geom/GeoBBox.h
# /kaggle/input/compiledlucene/bk/build/_lucene/org/apache/lucene/spatial3d/geom/GeoBaseAreaShape.h
# /kaggle/input/compiledlucene/bk/build/_lucene/org/apache/lucene/spatial3d/geom/GeoS2ShapeFactory.h
# /kaggle/input/compiledlucene/bk/build/_lucene/org/apache/lucene/spatial3d/geom/GeoCircle.h
# /kaggle/input/compiledlucene/bk/build/_lucene/org/apache/lucene/spatial3d/geom/GeoBaseMembershipShape.h
# /kaggle/input/compiledlucene/bk/build/_lucene/org/apache/lucene/spatial3d/geom/GeoAreaShape.h
# /kaggle/input/compiledlucene/bk/build/_lucene/org/apache/lucene/spatial3d/geom/BasePlanetObject.h
# /kaggle/input/compiledlucene/bk/build/_lucene/org/apache/lucene/spatial3d/geom/XYZSolidFactory.h
# /kaggle/input/compiledlucene/bk/build/_lucene/org/apache/lucene/spatial3d/geom/GeoPathFactory.h
# /kaggle/input/compiledlucene/bk/build/_lucene/org/apache/lucene/search/MultiTermQuery$TopTermsBlendedFreqScoringRewrite.h
# /kaggle/input/compiledlucene/bk/build/_lucene/org/apache/lucene/search/DocValuesStats$LongDocValuesStats.h
# /kaggle/input/compiledlucene/bk/build/_lucene/org/apache/lucene/search/FuzzyTermsEnum$LevenshteinAutomataAttributeImpl.h
# /kaggle/input/compiledlucene/bk/build/_lucene/org/apache/lucene/search/BooleanClause$Occur.h
# /kaggle/input/compiledlucene/bk/build/_lucene/org/apache/lucene/search/MaxNonCompetitiveBoostAttributeImpl.h
# /kaggle/input/compiledlucene/bk/build/_lucene/org/apache/lucene/search/NormsFieldExistsQuery.h
# /kaggle/input/compiledlucene/bk/build/_lucene/org/apache/lucene/search/MultiPhraseQuery$Builder.h
# /kaggle/input/compiledlucene/bk/build/_lucene/org/apache/lucene/search/IndexSearcher$LeafSlice.h
# /kaggle/input/compiledlucene/bk/build/_lucene/org/apache/lucene/search/PhraseQuery$Builder.h
# /kaggle/input/compiledlucene/bk/build/_lucene/org/apache/lucene/search/FieldComparator$LongComparator.h
# /kaggle/input/compiledlucene/bk/build/_lucene/org/apache/lucene/search/ScorerSupplier.h
# /kaggle/input/compiledlucene/bk/build/_lucene/org/apache/lucene/search/ReferenceManager.h
# /kaggle/input/compiledlucene/bk/build/_lucene/org/apache/lucene/search/SearcherManager.h
# /kaggle/input/compiledlucene/bk/build/_lucene/org/apache/lucene/search/BoostQuery.h
# /kaggle/input/compiledlucene/bk/build/_lucene/org/apache/lucene/search/TopDocsCollector.h
# /kaggle/input/compiledlucene/bk/build/_lucene/org/apache/lucene/search/FieldComparator$IntComparator.h
# /kaggle/input/compiledlucene/bk/build/_lucene/org/apache/lucene/search/QueryCache.h
# /kaggle/input/compiledlucene/bk/build/_lucene/org/apache/lucene/search/LeafSimScorer.h
# /kaggle/input/compiledlucene/bk/build/_lucene/org/apache/lucene/search/BlendedTermQuery$Builder.h
# /kaggle/input/compiledlucene/bk/build/_lucene/org/apache/lucene/search/DocValuesStats$SortedSetDocValuesStats.h
# /kaggle/input/compiledlucene/bk/build/_lucene/org/apache/lucene/search/Matches.h
# /kaggle/input/compiledlucene/bk/build/_lucene/org/apache/lucene/search/QueryCachingPolicy.h
# /kaggle/input/compiledlucene/bk/build/_lucene/org/apache/lucene/search/CollectorManager.h
# /kaggle/input/compiledlucene/bk/build/_lucene/org/apache/lucene/search/MatchNoDocsQuery.h
# /kaggle/input/compiledlucene/bk/build/_lucene/org/apache/lucene/search/TotalHits.h
# /kaggle/input/compiledlucene/bk/build/_lucene/org/apache/lucene/search/TermQuery.h
# /kaggle/input/compiledlucene/bk/build/_lucene/org/apache/lucene/search/MultiTermQuery$TopTermsBoostOnlyBooleanQueryRewrite.h
# /kaggle/input/compiledlucene/bk/build/_lucene/org/apache/lucene/search/BooleanClause.h
# /kaggle/input/compiledlucene/bk/build/_lucene/org/apache/lucene/search/Explanation.h
# /kaggle/input/compiledlucene/bk/build/_lucene/org/apache/lucene/search/FieldComparator$RelevanceComparator.h
# /kaggle/input/compiledlucene/bk/build/_lucene/org/apache/lucene/search/DisiPriorityQueue.h
# /kaggle/input/compiledlucene/bk/build/_lucene/org/apache/lucene/search/SortedSetSelector.h
# /kaggle/input/compiledlucene/bk/build/_lucene/org/apache/lucene/search/FieldComparator$DocComparator.h
# /kaggle/input/compiledlucene/bk/build/_lucene/org/apache/lucene/search/DocValuesStats$SortedDocValuesStats.h
# /kaggle/input/compiledlucene/bk/build/_lucene/org/apache/lucene/search/TimeLimitingCollector$TimeExceededException.h
# /kaggle/input/compiledlucene/bk/build/_lucene/org/apache/lucene/search/BlendedTermQuery.h
# /kaggle/input/compiledlucene/bk/build/_lucene/org/apache/lucene/search/SortRescorer.h
# /kaggle/input/compiledlucene/bk/build/_lucene/org/apache/lucene/search/FilterCollector.h
# /kaggle/input/compiledlucene/bk/build/_lucene/org/apache/lucene/search/LeafFieldComparator.h
# /kaggle/input/compiledlucene/bk/build/_lucene/org/apache/lucene/search/CollectionStatistics.h
# /kaggle/input/compiledlucene/bk/build/_lucene/org/apache/lucene/search/FilterScorable.h
# /kaggle/input/compiledlucene/bk/build/_lucene/org/apache/lucene/search/SortedSetSortField.h
# /kaggle/input/compiledlucene/bk/build/_lucene/org/apache/lucene/search/DisiWrapper.h
# /kaggle/input/compiledlucene/bk/build/_lucene/org/apache/lucene/search/QueryRescorer.h
# /kaggle/input/compiledlucene/bk/build/_lucene/org/apache/lucene/search/DocValuesNumbersQuery.h
# /kaggle/input/compiledlucene/bk/build/_lucene/org/apache/lucene/search/TokenStreamToTermAutomatonQuery.h
# /kaggle/input/compiledlucene/bk/build/_lucene/org/apache/lucene/search/FieldComparator$TermValComparator.h
# /kaggle/input/compiledlucene/bk/build/_lucene/org/apache/lucene/search/DisjunctionMaxQuery.h
# /kaggle/input/compiledlucene/bk/build/_lucene/org/apache/lucene/search/SearcherLifetimeManager.h
# /kaggle/input/compiledlucene/bk/build/_lucene/org/apache/lucene/search/Scorable$ChildScorable.h
# /kaggle/input/compiledlucene/bk/build/_lucene/org/apache/lucene/search/CollectionTerminatedException.h
# /kaggle/input/compiledlucene/bk/build/_lucene/org/apache/lucene/search/SimpleFieldComparator.h
# /kaggle/input/compiledlucene/bk/build/_lucene/org/apache/lucene/search/LatLonPointPrototypeQueries.h
# /kaggle/input/compiledlucene/bk/build/_lucene/org/apache/lucene/search/DocValuesStats.h
# /kaggle/input/compiledlucene/bk/build/_lucene/org/apache/lucene/search/MultiCollector.h
# /kaggle/input/compiledlucene/bk/build/_lucene/org/apache/lucene/search/DisjunctionDISIApproximation.h
# /kaggle/input/compiledlucene/bk/build/_lucene/org/apache/lucene/search/BoostAttributeImpl.h
# /kaggle/input/compiledlucene/bk/build/_lucene/org/apache/lucene/search/ScoringRewrite.h
# /kaggle/input/compiledlucene/bk/build/_lucene/org/apache/lucene/search/TermCollectingRewrite.h
# /kaggle/input/compiledlucene/bk/build/_lucene/org/apache/lucene/search/PointRangeQuery.h
# /kaggle/input/compiledlucene/bk/build/_lucene/org/apache/lucene/search/PositiveScoresOnlyCollector.h
# /kaggle/input/compiledlucene/bk/build/_lucene/org/apache/lucene/search/ImpactsDISI.h
# /kaggle/input/compiledlucene/bk/build/_lucene/org/apache/lucene/search/FilteredDocIdSetIterator.h
# /kaggle/input/compiledlucene/bk/build/_lucene/org/apache/lucene/search/DoubleValuesSource.h
# /kaggle/input/compiledlucene/bk/build/_lucene/org/apache/lucene/search/Scorer.h
# /kaggle/input/compiledlucene/bk/build/_lucene/org/apache/lucene/search/SynonymQuery$Builder.h
# /kaggle/input/compiledlucene/bk/build/_lucene/org/apache/lucene/search/MaxNonCompetitiveBoostAttribute.h
# /kaggle/input/compiledlucene/bk/build/_lucene/org/apache/lucene/search/ConstantScoreQuery.h
# /kaggle/input/compiledlucene/bk/build/_lucene/org/apache/lucene/search/DocIdSetIterator.h
# /kaggle/input/compiledlucene/bk/build/_lucene/org/apache/lucene/search/LongValuesSource.h
# /kaggle/input/compiledlucene/bk/build/_lucene/org/apache/lucene/search/PointInSetQuery$Stream.h
# /kaggle/input/compiledlucene/bk/build/_lucene/org/apache/lucene/search/IndexSearcher.h
# /kaggle/input/compiledlucene/bk/build/_lucene/org/apache/lucene/search/BooleanQuery.h
# /kaggle/input/compiledlucene/bk/build/_lucene/org/apache/lucene/search/FuzzyTermsEnum$LevenshteinAutomataAttribute.h
# /kaggle/input/compiledlucene/bk/build/_lucene/org/apache/lucene/search/SortedNumericSelector.h
# /kaggle/input/compiledlucene/bk/build/_lucene/org/apache/lucene/search/FieldComparator$NumericComparator.h
# /kaggle/input/compiledlucene/bk/build/_lucene/org/apache/lucene/search/Collector.h
# /kaggle/input/compiledlucene/bk/build/_lucene/org/apache/lucene/search/TotalHits$Relation.h
# /kaggle/input/compiledlucene/bk/build/_lucene/org/apache/lucene/search/SearcherFactory.h
# /kaggle/input/compiledlucene/bk/build/_lucene/org/apache/lucene/search/SortField$Type.h
# /kaggle/input/compiledlucene/bk/build/_lucene/org/apache/lucene/search/DiversifiedTopDocsCollector.h
# /kaggle/input/compiledlucene/bk/build/_lucene/org/apache/lucene/search/LeafCollector.h
# /kaggle/input/compiledlucene/bk/build/_lucene/org/apache/lucene/search/BlendedTermQuery$DisjunctionMaxRewrite.h
# /kaggle/input/compiledlucene/bk/build/_lucene/org/apache/lucene/search/BulkScorer.h
# /kaggle/input/compiledlucene/bk/build/_lucene/org/apache/lucene/search/CoveringQuery.h
# /kaggle/input/compiledlucene/bk/build/_lucene/org/apache/lucene/search/SegmentCacheable.h
# /kaggle/input/compiledlucene/bk/build/_lucene/org/apache/lucene/search/DocValuesRewriteMethod.h
# /kaggle/input/compiledlucene/bk/build/_lucene/org/apache/lucene/search/SortField.h
# /kaggle/input/compiledlucene/bk/build/_lucene/org/apache/lucene/search/TermRangeQuery.h
# /kaggle/input/compiledlucene/bk/build/_lucene/org/apache/lucene/search/MatchesIterator.h
# /kaggle/input/compiledlucene/bk/build/_lucene/org/apache/lucene/search/TopScoreDocCollector.h
# /kaggle/input/compiledlucene/bk/build/_lucene/org/apache/lucene/search/BoostAttribute.h
# /kaggle/input/compiledlucene/bk/build/_lucene/org/apache/lucene/search/LRUQueryCache.h
# /kaggle/input/compiledlucene/bk/build/_lucene/org/apache/lucene/search/UsageTrackingQueryCachingPolicy.h
# /kaggle/input/compiledlucene/bk/build/_lucene/org/apache/lucene/search/ScoreDoc.h
# /kaggle/input/compiledlucene/bk/build/_lucene/org/apache/lucene/search/CachingCollector.h
# /kaggle/input/compiledlucene/bk/build/_lucene/org/apache/lucene/search/DiversifiedTopDocsCollector$ScoreDocKey.h
# /kaggle/input/compiledlucene/bk/build/_lucene/org/apache/lucene/search/PhraseQuery.h
# /kaggle/input/compiledlucene/bk/build/_lucene/org/apache/lucene/search/MultiPhraseQuery.h
# /kaggle/input/compiledlucene/bk/build/_lucene/org/apache/lucene/search/BooleanQuery$TooManyClauses.h
# /kaggle/input/compiledlucene/bk/build/_lucene/org/apache/lucene/search/DocValuesStatsCollector.h
# /kaggle/input/compiledlucene/bk/build/_lucene/org/apache/lucene/search/TwoPhaseIterator.h
# /kaggle/input/compiledlucene/bk/build/_lucene/org/apache/lucene/search/SearcherLifetimeManager$PruneByAge.h
# /kaggle/input/compiledlucene/bk/build/_lucene/org/apache/lucene/search/LiveFieldValues.h
# /kaggle/input/compiledlucene/bk/build/_lucene/org/apache/lucene/search/Query.h
# /kaggle/input/compiledlucene/bk/build/_lucene/org/apache/lucene/search/SearcherLifetimeManager$Pruner.h
# /kaggle/input/compiledlucene/bk/build/_lucene/org/apache/lucene/search/Scorable.h
# /kaggle/input/compiledlucene/bk/build/_lucene/org/apache/lucene/search/FieldComparatorSource.h
# /kaggle/input/compiledlucene/bk/build/_lucene/org/apache/lucene/search/SortedNumericSortField.h
# /kaggle/input/compiledlucene/bk/build/_lucene/org/apache/lucene/search/MultiCollectorManager$Collectors$LeafCollectors.h
# /kaggle/input/compiledlucene/bk/build/_lucene/org/apache/lucene/search/FuzzyQuery.h
# /kaggle/input/compiledlucene/bk/build/_lucene/org/apache/lucene/search/FieldComparator$DoubleComparator.h
# /kaggle/input/compiledlucene/bk/build/_lucene/org/apache/lucene/search/BM25FQuery.h
# /kaggle/input/compiledlucene/bk/build/_lucene/org/apache/lucene/search/ConstantScoreWeight.h
# /kaggle/input/compiledlucene/bk/build/_lucene/org/apache/lucene/search/MultiTermQuery$RewriteMethod.h
# /kaggle/input/compiledlucene/bk/build/_lucene/org/apache/lucene/search/TopFieldCollector.h
# /kaggle/input/compiledlucene/bk/build/_lucene/org/apache/lucene/search/DocValuesFieldExistsQuery.h
# /kaggle/input/compiledlucene/bk/build/_lucene/org/apache/lucene/search/DocValuesTermsQuery.h
# /kaggle/input/compiledlucene/bk/build/_lucene/org/apache/lucene/search/Rescorer.h
# /kaggle/input/compiledlucene/bk/build/_lucene/org/apache/lucene/search/DocValuesStats$NumericDocValuesStats.h
# /kaggle/input/compiledlucene/bk/build/_lucene/org/apache/lucene/search/FieldComparator$FloatComparator.h
# /kaggle/input/compiledlucene/bk/build/_lucene/org/apache/lucene/search/DocValuesStats$SortedDoubleDocValuesStats.h
# /kaggle/input/compiledlucene/bk/build/_lucene/org/apache/lucene/search/FieldDoc.h
# /kaggle/input/compiledlucene/bk/build/_lucene/org/apache/lucene/search/NGramPhraseQuery.h
# /kaggle/input/compiledlucene/bk/build/_lucene/org/apache/lucene/search/SortedNumericSelector$Type.h
# /kaggle/input/compiledlucene/bk/build/_lucene/org/apache/lucene/search/DocValuesStats$SortedLongDocValuesStats.h
# /kaggle/input/compiledlucene/bk/build/_lucene/org/apache/lucene/search/LongValues.h
# /kaggle/input/compiledlucene/bk/build/_lucene/org/apache/lucene/search/SortedSetSelector$Type.h
# /kaggle/input/compiledlucene/bk/build/_lucene/org/apache/lucene/search/MultiTermQuery.h
# /kaggle/input/compiledlucene/bk/build/_lucene/org/apache/lucene/search/DocIdSet.h
# /kaggle/input/compiledlucene/bk/build/_lucene/org/apache/lucene/search/ControlledRealTimeReopenThread.h
# /kaggle/input/compiledlucene/bk/build/_lucene/org/apache/lucene/search/TopFieldDocs.h
# /kaggle/input/compiledlucene/bk/build/_lucene/org/apache/lucene/search/FilterWeight.h
# /kaggle/input/compiledlucene/bk/build/_lucene/org/apache/lucene/search/TimeLimitingCollector$TimerThread.h
# /kaggle/input/compiledlucene/bk/build/_lucene/org/apache/lucene/search/BlendedTermQuery$RewriteMethod.h
# /kaggle/input/compiledlucene/bk/build/_lucene/org/apache/lucene/search/FilterMatchesIterator.h
# /kaggle/input/compiledlucene/bk/build/_lucene/org/apache/lucene/search/FieldComparator$TermOrdValComparator.h
# /kaggle/input/compiledlucene/bk/build/_lucene/org/apache/lucene/search/ReferenceManager$RefreshListener.h
# /kaggle/input/compiledlucene/bk/build/_lucene/org/apache/lucene/search/WildcardQuery.h
# /kaggle/input/compiledlucene/bk/build/_lucene/org/apache/lucene/search/FuzzyTermsEnum.h
# /kaggle/input/compiledlucene/bk/build/_lucene/org/apache/lucene/search/TotalHitCountCollector.h
# /kaggle/input/compiledlucene/bk/build/_lucene/org/apache/lucene/search/FieldValueHitQueue$Entry.h
# /kaggle/input/compiledlucene/bk/build/_lucene/org/apache/lucene/search/FilterLeafCollector.h
# /kaggle/input/compiledlucene/bk/build/_lucene/org/apache/lucene/search/RegexpQuery.h
# /kaggle/input/compiledlucene/bk/build/_lucene/org/apache/lucene/search/TermInSetQuery.h
# /kaggle/input/compiledlucene/bk/build/_lucene/org/apache/lucene/search/DocValuesStats$SortedNumericDocValuesStats.h
# /kaggle/input/compiledlucene/bk/build/_lucene/org/apache/lucene/search/SynonymQuery.h
# ...
# /kaggle/input/compiledlucene/bk/build/_lucene/org/apache/lucene/queryparser/xml/builders/ConstantScoreQueryBuilder.h
# /kaggle/input/compiledlucene/bk/build/_lucene/org/apache/lucene/queryparser/xml/builders/TermQueryBuilder.h
# /kaggle/input/compiledlucene/bk/build/_lucene/org/apache/lucene/queryparser/xml/builders/LikeThisQueryBuilder.h
# /kaggle/input/compiledlucene/bk/build/_lucene/org/apache/lucene/queryparser/xml/builders/DisjunctionMaxQueryBuilder.h
# /kaggle/input/compiledlucene/bk/build/_lucene/org/apache/lucene/queryparser/xml/builders/BoostingTermBuilder.h
# /kaggle/input/compiledlucene/bk/build/_lucene/org/apache/lucene/queryparser/xml/builders/SpanOrBuilder.h
# /kaggle/input/compiledlucene/bk/build/_lucene/org/apache/lucene/queryparser/xml/builders/RangeQueryBuilder.h
# /kaggle/input/compiledlucene/bk/build/_lucene/org/apache/lucene/queryparser/xml/builders/TermsQueryBuilder.h
# /kaggle/input/compiledlucene/bk/build/_lucene/org/apache/lucene/queryparser/xml/builders/UserInputQueryBuilder.h
# /kaggle/input/compiledlucene/bk/build/_lucene/org/apache/lucene/queryparser/xml/builders/FuzzyLikeThisQueryBuilder.h
# /kaggle/input/compiledlucene/bk/build/_lucene/org/apache/lucene/queryparser/xml/builders/SpanBuilderBase.h
# /kaggle/input/compiledlucene/bk/build/_lucene/org/apache/lucene/queryparser/xml/builders/PointRangeQueryBuilder.h
# /kaggle/input/compiledlucene/bk/build/_lucene/org/apache/lucene/queryparser/xml/builders/SpanQueryBuilderFactory.h
# /kaggle/input/compiledlucene/bk/build/_lucene/org/apache/lucene/queryparser/xml/builders/BooleanQueryBuilder.h
# /kaggle/input/compiledlucene/bk/build/_lucene/org/apache/lucene/queryparser/xml/builders/SpanQueryBuilder.h
# /kaggle/input/compiledlucene/bk/build/_lucene/org/apache/lucene/queryparser/complexPhrase/ComplexPhraseQueryParser.h
# /kaggle/input/compiledlucene/bk/build/_lucene/org/apache/lucene/queryparser/ext/ExtendableQueryParser.h
# /kaggle/input/compiledlucene/bk/build/_lucene/org/apache/lucene/queryparser/ext/Extensions.h
# /kaggle/input/compiledlucene/bk/build/_lucene/org/apache/lucene/queryparser/ext/ExtensionQuery.h
# /kaggle/input/compiledlucene/bk/build/_lucene/org/apache/lucene/queryparser/ext/ParserExtension.h
# /kaggle/input/compiledlucene/bk/build/_lucene/org/apache/lucene/queryparser/ext/Extensions$Pair.h
# /kaggle/input/compiledlucene/bk/build/_lucene/org/apache/lucene/queryparser/classic/ParseException.h
# /kaggle/input/compiledlucene/bk/build/_lucene/org/apache/lucene/queryparser/classic/QueryParser.h
# /kaggle/input/compiledlucene/bk/build/_lucene/org/apache/lucene/queryparser/classic/MultiFieldQueryParser.h
# /kaggle/input/compiledlucene/bk/build/_lucene/org/apache/lucene/queryparser/classic/TokenMgrError.h
# /kaggle/input/compiledlucene/bk/build/_lucene/org/apache/lucene/queryparser/classic/CharStream.h
# /kaggle/input/compiledlucene/bk/build/_lucene/org/apache/lucene/queryparser/classic/QueryParser$Operator.h
# /kaggle/input/compiledlucene/bk/build/_lucene/org/apache/lucene/queryparser/classic/QueryParserConstants.h
# /kaggle/input/compiledlucene/bk/build/_lucene/org/apache/lucene/queryparser/classic/Token.h
# /kaggle/input/compiledlucene/bk/build/_lucene/org/apache/lucene/queryparser/classic/QueryParserBase.h
# /kaggle/input/compiledlucene/bk/build/_lucene/org/apache/lucene/queryparser/classic/QueryParserTokenManager.h
# /kaggle/input/compiledlucene/bk/build/_lucene/org/apache/lucene/queryparser/classic/FastCharStream.h
# /kaggle/input/compiledlucene/bk/build/_lucene/org/apache/lucene/queryparser/simple/SimpleQueryParser.h
# /kaggle/input/compiledlucene/bk/build/_lucene/org/apache/lucene/sandbox/queries/FuzzyLikeThisQuery.h
# /kaggle/input/compiledlucene/bk/build/lib.linux-x86_64-3.6/lucene/antlr4-runtime-4.5.1-1.jar
# /kaggle/input/compiledlucene/bk/build/lib.linux-x86_64-3.6/lucene/hppc-0.8.1.jar
# /kaggle/input/compiledlucene/bk/build/lib.linux-x86_64-3.6/lucene/lucene-analyzers-stempel-8.1.1.jar
# /kaggle/input/compiledlucene/bk/build/lib.linux-x86_64-3.6/lucene/lucene-analyzers-kuromoji-8.1.1.jar
# /kaggle/input/compiledlucene/bk/build/lib.linux-x86_64-3.6/lucene/lucene-analyzers-nori-8.1.1.jar
# /kaggle/input/compiledlucene/bk/build/lib.linux-x86_64-3.6/lucene/asm-commons-5.1.jar
# /kaggle/input/compiledlucene/bk/build/lib.linux-x86_64-3.6/lucene/ICUNormalizer2Filter.py
# /kaggle/input/compiledlucene/bk/build/lib.linux-x86_64-3.6/lucene/collections.py
# /kaggle/input/compiledlucene/bk/build/lib.linux-x86_64-3.6/lucene/extensions.jar
# /kaggle/input/compiledlucene/bk/build/lib.linux-x86_64-3.6/lucene/lucene-spatial3d-8.1.1.jar
# /kaggle/input/compiledlucene/bk/build/lib.linux-x86_64-3.6/lucene/lucene-join-8.1.1.jar
# /kaggle/input/compiledlucene/bk/build/lib.linux-x86_64-3.6/lucene/lucene-suggest-8.1.1.jar
# /kaggle/input/compiledlucene/bk/build/lib.linux-x86_64-3.6/lucene/lucene-highlighter-8.1.1.jar
# /kaggle/input/compiledlucene/bk/build/lib.linux-x86_64-3.6/lucene/lucene-analyzers-common-8.1.1.jar
# /kaggle/input/compiledlucene/bk/build/lib.linux-x86_64-3.6/lucene/_lucene.cpython-36m-x86_64-linux-gnu.so
# /kaggle/input/compiledlucene/bk/build/lib.linux-x86_64-3.6/lucene/lucene-backward-codecs-8.1.1.jar
# /kaggle/input/compiledlucene/bk/build/lib.linux-x86_64-3.6/lucene/lucene-sandbox-8.1.1.jar
# /kaggle/input/compiledlucene/bk/build/lib.linux-x86_64-3.6/lucene/lucene-expressions-8.1.1.jar
# /kaggle/input/compiledlucene/bk/build/lib.linux-x86_64-3.6/lucene/__init__.py
# /kaggle/input/compiledlucene/bk/build/lib.linux-x86_64-3.6/lucene/lucene-spatial-8.1.1.jar
# /kaggle/input/compiledlucene/bk/build/lib.linux-x86_64-3.6/lucene/lucene-grouping-8.1.1.jar
# /kaggle/input/compiledlucene/bk/build/lib.linux-x86_64-3.6/lucene/lucene-queries-8.1.1.jar
# /kaggle/input/compiledlucene/bk/build/lib.linux-x86_64-3.6/lucene/lucene-core-8.1.1.jar
# /kaggle/input/compiledlucene/bk/build/lib.linux-x86_64-3.6/lucene/lucene-memory-8.1.1.jar
# /kaggle/input/compiledlucene/bk/build/lib.linux-x86_64-3.6/lucene/lucene-facet-8.1.1.jar
# /kaggle/input/compiledlucene/bk/build/lib.linux-x86_64-3.6/lucene/ICUFoldingFilter.py
# /kaggle/input/compiledlucene/bk/build/lib.linux-x86_64-3.6/lucene/asm-5.1.jar
# /kaggle/input/compiledlucene/bk/build/lib.linux-x86_64-3.6/lucene/lucene-classification-8.1.1.jar
# /kaggle/input/compiledlucene/bk/build/lib.linux-x86_64-3.6/lucene/lucene-queryparser-8.1.1.jar
# /kaggle/input/compiledlucene/bk/build/lib.linux-x86_64-3.6/lucene/lucene-codecs-8.1.1.jar
# /kaggle/input/compiledlucene/bk/build/lib.linux-x86_64-3.6/lucene/lucene-misc-8.1.1.jar
# /kaggle/input/compiledlucene/bk/build/lib.linux-x86_64-3.6/lucene/ICUTransformFilter.py
# /kaggle/input/compiledlucene/bk/build/classes/org/apache/pylucene/search/PythonSimpleCollector.class
# /kaggle/input/compiledlucene/bk/build/classes/org/apache/pylucene/search/highlight/PythonFormatter.class
# /kaggle/input/compiledlucene/bk/build/classes/org/apache/pylucene/search/highlight/PythonFragmenter.class
# /kaggle/input/compiledlucene/bk/build/classes/org/apache/pylucene/search/similarities/PythonSimilarity$PythonSimScorer.class
# /kaggle/input/compiledlucene/bk/build/classes/org/apache/pylucene/search/similarities/PythonSimilarity.class
# /kaggle/input/compiledlucene/bk/build/classes/org/apache/pylucene/search/similarities/PythonPerFieldSimilarityWrapper.class
# /kaggle/input/compiledlucene/bk/build/classes/org/apache/pylucene/search/similarities/PythonClassicSimilarity.class
# /kaggle/input/compiledlucene/bk/build/classes/org/apache/pylucene/search/spans/PythonSpanCollector.class
# /kaggle/input/compiledlucene/bk/build/classes/org/apache/pylucene/store/PythonIndexOutput.class
# /kaggle/input/compiledlucene/bk/build/classes/org/apache/pylucene/store/PythonLock.class
# /kaggle/input/compiledlucene/bk/build/classes/org/apache/pylucene/store/PythonDirectory.class
# /kaggle/input/compiledlucene/bk/build/classes/org/apache/pylucene/store/PythonIndexInput.class
# /kaggle/input/compiledlucene/bk/build/classes/org/apache/pylucene/store/PythonLockFactory.class
# /kaggle/input/compiledlucene/bk/build/classes/org/apache/pylucene/analysis/PythonTokenizer.class
# /kaggle/input/compiledlucene/bk/build/classes/org/apache/pylucene/analysis/PythonAnalyzer.class
# /kaggle/input/compiledlucene/bk/build/classes/org/apache/pylucene/analysis/PythonTokenStream.class
# /kaggle/input/compiledlucene/bk/build/classes/org/apache/pylucene/analysis/PythonTokenFilter.class
# /kaggle/input/compiledlucene/bk/build/classes/org/apache/pylucene/analysis/PythonFilteringTokenFilter.class
# /kaggle/input/compiledlucene/bk/build/classes/org/apache/pylucene/util/PythonAttribute.class
# /kaggle/input/compiledlucene/bk/build/classes/org/apache/pylucene/util/PythonList.class
# /kaggle/input/compiledlucene/bk/build/classes/org/apache/pylucene/util/PythonIterator.class
# /kaggle/input/compiledlucene/bk/build/classes/org/apache/pylucene/util/PythonListIterator.class
# /kaggle/input/compiledlucene/bk/build/classes/org/apache/pylucene/util/PythonComparable.class
# /kaggle/input/compiledlucene/bk/build/classes/org/apache/pylucene/util/PythonSet.class
# /kaggle/input/compiledlucene/bk/build/classes/org/apache/pylucene/util/PythonAttributeImpl.class
# /kaggle/input/compiledlucene/bk/build/classes/org/apache/pylucene/index/PythonIndexDeletionPolicy.class
# /kaggle/input/compiledlucene/bk/build/classes/org/apache/pylucene/queryparser/classic/PythonQueryParser.class
# /kaggle/input/compiledlucene/bk/build/classes/org/apache/pylucene/queryparser/classic/PythonMultiFieldQueryParser.class
# /kaggle/input/compiledlucene/bk/build/test/site.py
# /kaggle/input/compiledlucene/bk/build/test/easy-install.pth
# /kaggle/input/compiledlucene/bk/build/test/lucene-8.1.1-py3.6-linux-x86_64.egg/EGG-INFO/not-zip-safe
# /kaggle/input/compiledlucene/bk/build/test/lucene-8.1.1-py3.6-linux-x86_64.egg/EGG-INFO/PKG-INFO
# /kaggle/input/compiledlucene/bk/build/test/lucene-8.1.1-py3.6-linux-x86_64.egg/EGG-INFO/native_libs.txt
# /kaggle/input/compiledlucene/bk/build/test/lucene-8.1.1-py3.6-linux-x86_64.egg/EGG-INFO/dependency_links.txt
# /kaggle/input/compiledlucene/bk/build/test/lucene-8.1.1-py3.6-linux-x86_64.egg/EGG-INFO/top_level.txt
# /kaggle/input/compiledlucene/bk/build/test/lucene-8.1.1-py3.6-linux-x86_64.egg/EGG-INFO/SOURCES.txt
# /kaggle/input/compiledlucene/bk/build/test/lucene-8.1.1-py3.6-linux-x86_64.egg/lucene/antlr4-runtime-4.5.1-1.jar
# /kaggle/input/compiledlucene/bk/build/test/lucene-8.1.1-py3.6-linux-x86_64.egg/lucene/hppc-0.8.1.jar
# /kaggle/input/compiledlucene/bk/build/test/lucene-8.1.1-py3.6-linux-x86_64.egg/lucene/lucene-analyzers-stempel-8.1.1.jar
# /kaggle/input/compiledlucene/bk/build/test/lucene-8.1.1-py3.6-linux-x86_64.egg/lucene/lucene-analyzers-kuromoji-8.1.1.jar
# /kaggle/input/compiledlucene/bk/build/test/lucene-8.1.1-py3.6-linux-x86_64.egg/lucene/lucene-analyzers-nori-8.1.1.jar
# /kaggle/input/compiledlucene/bk/build/test/lucene-8.1.1-py3.6-linux-x86_64.egg/lucene/asm-commons-5.1.jar
# /kaggle/input/compiledlucene/bk/build/test/lucene-8.1.1-py3.6-linux-x86_64.egg/lucene/ICUNormalizer2Filter.py
# /kaggle/input/compiledlucene/bk/build/test/lucene-8.1.1-py3.6-linux-x86_64.egg/lucene/collections.py
# /kaggle/input/compiledlucene/bk/build/test/lucene-8.1.1-py3.6-linux-x86_64.egg/lucene/extensions.jar
# /kaggle/input/compiledlucene/bk/build/test/lucene-8.1.1-py3.6-linux-x86_64.egg/lucene/lucene-spatial3d-8.1.1.jar
# /kaggle/input/compiledlucene/bk/build/test/lucene-8.1.1-py3.6-linux-x86_64.egg/lucene/lucene-join-8.1.1.jar
# /kaggle/input/compiledlucene/bk/build/test/lucene-8.1.1-py3.6-linux-x86_64.egg/lucene/lucene-suggest-8.1.1.jar
# /kaggle/input/compiledlucene/bk/build/test/lucene-8.1.1-py3.6-linux-x86_64.egg/lucene/lucene-highlighter-8.1.1.jar
# /kaggle/input/compiledlucene/bk/build/test/lucene-8.1.1-py3.6-linux-x86_64.egg/lucene/lucene-analyzers-common-8.1.1.jar
# /kaggle/input/compiledlucene/bk/build/test/lucene-8.1.1-py3.6-linux-x86_64.egg/lucene/_lucene.py
# /kaggle/input/compiledlucene/bk/build/test/lucene-8.1.1-py3.6-linux-x86_64.egg/lucene/_lucene.cpython-36m-x86_64-linux-gnu.so
# /kaggle/input/compiledlucene/bk/build/test/lucene-8.1.1-py3.6-linux-x86_64.egg/lucene/lucene-backward-codecs-8.1.1.jar
# /kaggle/input/compiledlucene/bk/build/test/lucene-8.1.1-py3.6-linux-x86_64.egg/lucene/lucene-sandbox-8.1.1.jar
# /kaggle/input/compiledlucene/bk/build/test/lucene-8.1.1-py3.6-linux-x86_64.egg/lucene/lucene-expressions-8.1.1.jar
# /kaggle/input/compiledlucene/bk/build/test/lucene-8.1.1-py3.6-linux-x86_64.egg/lucene/__init__.py
# /kaggle/input/compiledlucene/bk/build/test/lucene-8.1.1-py3.6-linux-x86_64.egg/lucene/lucene-spatial-8.1.1.jar
# /kaggle/input/compiledlucene/bk/build/test/lucene-8.1.1-py3.6-linux-x86_64.egg/lucene/lucene-grouping-8.1.1.jar
# /kaggle/input/compiledlucene/bk/build/test/lucene-8.1.1-py3.6-linux-x86_64.egg/lucene/lucene-queries-8.1.1.jar
# /kaggle/input/compiledlucene/bk/build/test/lucene-8.1.1-py3.6-linux-x86_64.egg/lucene/lucene-core-8.1.1.jar
# /kaggle/input/compiledlucene/bk/build/test/lucene-8.1.1-py3.6-linux-x86_64.egg/lucene/lucene-memory-8.1.1.jar
# /kaggle/input/compiledlucene/bk/build/test/lucene-8.1.1-py3.6-linux-x86_64.egg/lucene/lucene-facet-8.1.1.jar
# /kaggle/input/compiledlucene/bk/build/test/lucene-8.1.1-py3.6-linux-x86_64.egg/lucene/ICUFoldingFilter.py
# /kaggle/input/compiledlucene/bk/build/test/lucene-8.1.1-py3.6-linux-x86_64.egg/lucene/asm-5.1.jar
# /kaggle/input/compiledlucene/bk/build/test/lucene-8.1.1-py3.6-linux-x86_64.egg/lucene/lucene-classification-8.1.1.jar
# /kaggle/input/compiledlucene/bk/build/test/lucene-8.1.1-py3.6-linux-x86_64.egg/lucene/lucene-queryparser-8.1.1.jar
# /kaggle/input/compiledlucene/bk/build/test/lucene-8.1.1-py3.6-linux-x86_64.egg/lucene/lucene-codecs-8.1.1.jar
# /kaggle/input/compiledlucene/bk/build/test/lucene-8.1.1-py3.6-linux-x86_64.egg/lucene/lucene-misc-8.1.1.jar
# /kaggle/input/compiledlucene/bk/build/test/lucene-8.1.1-py3.6-linux-x86_64.egg/lucene/ICUTransformFilter.py
# /kaggle/input/compiledlucene/bk/build/lucene/antlr4-runtime-4.5.1-1.jar
# /kaggle/input/compiledlucene/bk/build/lucene/hppc-0.8.1.jar
# /kaggle/input/compiledlucene/bk/build/lucene/lucene-analyzers-stempel-8.1.1.jar
# /kaggle/input/compiledlucene/bk/build/lucene/lucene-analyzers-kuromoji-8.1.1.jar
# /kaggle/input/compiledlucene/bk/build/lucene/lucene-analyzers-nori-8.1.1.jar
# /kaggle/input/compiledlucene/bk/build/lucene/asm-commons-5.1.jar
# /kaggle/input/compiledlucene/bk/build/lucene/ICUNormalizer2Filter.py
# /kaggle/input/compiledlucene/bk/build/lucene/collections.py
# /kaggle/input/compiledlucene/bk/build/lucene/extensions.jar
# /kaggle/input/compiledlucene/bk/build/lucene/lucene-spatial3d-8.1.1.jar
# /kaggle/input/compiledlucene/bk/build/lucene/lucene-join-8.1.1.jar
# /kaggle/input/compiledlucene/bk/build/lucene/lucene-suggest-8.1.1.jar
# /kaggle/input/compiledlucene/bk/build/lucene/lucene-highlighter-8.1.1.jar
# /kaggle/input/compiledlucene/bk/build/lucene/lucene-analyzers-common-8.1.1.jar
# /kaggle/input/compiledlucene/bk/build/lucene/lucene-backward-codecs-8.1.1.jar
# /kaggle/input/compiledlucene/bk/build/lucene/lucene-sandbox-8.1.1.jar
# /kaggle/input/compiledlucene/bk/build/lucene/lucene-expressions-8.1.1.jar
# /kaggle/input/compiledlucene/bk/build/lucene/__init__.py
# /kaggle/input/compiledlucene/bk/build/lucene/lucene-spatial-8.1.1.jar
# /kaggle/input/compiledlucene/bk/build/lucene/lucene-grouping-8.1.1.jar
# /kaggle/input/compiledlucene/bk/build/lucene/lucene-queries-8.1.1.jar
# /kaggle/input/compiledlucene/bk/build/lucene/lucene-core-8.1.1.jar
# /kaggle/input/compiledlucene/bk/build/lucene/lucene-memory-8.1.1.jar
# /kaggle/input/compiledlucene/bk/build/lucene/lucene-facet-8.1.1.jar
# /kaggle/input/compiledlucene/bk/build/lucene/ICUFoldingFilter.py
# /kaggle/input/compiledlucene/bk/build/lucene/asm-5.1.jar
# /kaggle/input/compiledlucene/bk/build/lucene/lucene-classification-8.1.1.jar
# /kaggle/input/compiledlucene/bk/build/lucene/lucene-queryparser-8.1.1.jar
# /kaggle/input/compiledlucene/bk/build/lucene/lucene-codecs-8.1.1.jar
# /kaggle/input/compiledlucene/bk/build/lucene/lucene-misc-8.1.1.jar
# /kaggle/input/compiledlucene/bk/build/lucene/ICUTransformFilter.py
# /kaggle/input/ms-marco-queries/msmarco-doctrain-queries.tsv

# %%
pip install fast-autocomplete
# Out:
# Collecting fast-autocomplete
#   Downloading fast_autocomplete-0.6.0-py3-none-any.whl (22 kB)
# Requirement already satisfied: python-Levenshtein>=0.12.0 in /opt/conda/lib/python3.7/site-packages (from fast-autocomplete) (0.12.0)
# Requirement already satisfied: setuptools in /opt/conda/lib/python3.7/site-packages (from python-Levenshtein>=0.12.0->fast-autocomplete) (46.1.3.post20200325)
# Installing collected packages: fast-autocomplete
# Successfully installed fast-autocomplete-0.6.0
# WARNING: You are using pip version 20.2.1; however, version 20.2.3 is available.
# You should consider upgrading via the '/opt/conda/bin/python3.7 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install lupyne

# %%
pip install editdistance
# Out:
# Collecting editdistance
#   Downloading editdistance-0.5.3-cp37-cp37m-manylinux1_x86_64.whl (179 kB)
#      |████████████████████████████████| 179 kB 1.3 MB/s eta 0:00:01
# Installing collected packages: editdistance
# Successfully installed editdistance-0.5.3
# WARNING: You are using pip version 20.2.1; however, version 20.2.3 is available.
# You should consider upgrading via the '/opt/conda/bin/python3.7 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pylucene4

# %%
import requests
import random
import editdistance

from tqdm import tqdm
tqdm.pandas()
# Out:
# /opt/conda/lib/python3.7/site-packages/tqdm/std.py:666: FutureWarning: The Panel class is removed from pandas. Accessing it from the top-level namespace will also be removed in the next version
#   from pandas import Panel

# %% [markdown]
# # 1. Importing Files

# %%
queries_df = pd.read_csv('../input/ms-marco-queries/msmarco-doctrain-queries.tsv', sep = '\t', names = ['qid','query'])
queries_df = queries_df.set_index('qid')
display(queries_df.head(10))
display(queries_df.tail(10))
print(len(queries_df.index))
# Out:
#                                                      query
# qid
# 1185869  )what was the immediate impact of the success ...
# 1185868  _________ justice is designed to repair the ha...
# 1183785                                     elegxo meaning
# 645590                      what does physical medicine do
# 186154          feeding rice cereal how many times per day
# 457407                     most dependable affordable cars
# 441383                               lithophile definition
# 683408                               what is a flail chest
# 484187              put yourself on child support in texas
# 666321                      what happens in a wrist sprain
#                                             query
# qid
# 234427           how fast should a power chair go
# 285891       how many hours do you need for an aa
# 1164802                    what causes dry cough?
# 87046            causes of irritated mouth tissue
# 562255                        what are nephridia?
# 19285                  anterolisthesis definition
# 558837                     what are fishing flies
# 559149   what are fsh levels during perimenopause
# 706678                            what is a yowie
# 405466                   is carbonic acid soluble
# 367013

# %%
print(os.listdir('./')) # This will print the content of current directory
print(os.listdir('../input')) # This will print the content of input directory

# %%
# Install and import relevant libraries
# !python -m easy_install ../input/compiledlucene/bk/lucene-8.1.1-py3.6-linux-x86_64.egg
# !cp -r ../input/compiledlucene/bk/JCC-3.7-py3.6-linux-x86_64.egg /opt/conda/lib/python3.6/site-packages/
import sys
sys.path
sys.path.append('/opt/conda/lib/python3.6/site-packages/JCC-3.7-py3.6-linux-x86_64.egg')
sys.path.append('/opt/conda/lib/python3.6/site-packages/lucene-8.1.1-py3.6-linux-x86_64.egg')

# %%
import lucene

# %% [markdown]
# # 2. EDA

# %%
# Let's first check for any null rows

null_rows = queries_df[queries_df.isnull().any(axis = 1)]
display(null_rows)

# Cool, there aren't any
# Out:
# Empty DataFrame
# Columns: [query]
# Index: []

# %%
# Now let's try to find the average length of a query

def return_length(n):
    return len(n)

total_len = np.sum(queries_df['query'].apply(return_length))
average_query_length = total_len/len(queries_df)
print(total_len)
print(average_query_length)

# 33 characters seems reasonable.
# Out:
# 12163703
# 33.14243092206543

# %%
# Average number of word counts in the query

def number_of_words(n):
    words = n.split(' ')
    return len(words)

total_word_count = np.sum(queries_df['query'].apply(number_of_words))
average_word_count = total_word_count/len(queries_df)
print(total_word_count)
print(average_word_count)

# An average word count of 6 seems about right for a query
# Out:
# 2185955
# 5.956069676006027

# %%
# Let's now create a corpus of the 2.1M words used in the queries

def build_vocab(sentences, verbose =  True):
    vocab = {}
    for sentence in tqdm(sentences, disable = (not verbose)):
        for word in sentence.split(' '):
            try:
                vocab[word] += 1
            except KeyError:
                vocab[word] = 1
    return vocab

sentences = queries_df['query'].values
# print(sentences)
vocab = build_vocab(sentences)
print({k: vocab[k] for k in list(vocab)[:5]})

# As we can see, there are some tokens that are misspelled. I'll have to handle that later
# Out:
# 100%|██████████| 367013/367013 [00:01<00:00, 290640.29it/s]
# {')what': 1, 'was': 10493, 'the': 77087, 'immediate': 27, 'impact': 153}

# %%
# Let's now sort the vocab, that way we can remove the mispelled words

sorted_vocab = sorted(vocab.items(), key=lambda x: x[1], reverse=True)

# Let's first the see the top 10 most common words in the text, and their counts
print(sorted_vocab[:5])

# Let's now have a look at the last 50 terms in the sorted list (they will most probably be mispellings)
print(sorted_vocab[-50:])


# WOAH!! This is surprising, the last items of the sorted list, aren't actually mispelling, but many of them are just words ending with a question mark or bracket. I am gonna leave them be for now.
# Out:
# [('what', 147773), ('is', 133329), ('the', 77087), ('of', 59991), ('a', 55371)]
# [('abbati', 1), ('ridgedale', 1), ('diffuses', 1), ('metts', 1), ('pedipalp', 1), ('synulox', 1), ('pureblood', 1), ('atd', 1), ('westheimer', 1), ('tears?', 1), ('creo', 1), ('air,', 1), ('bulbasaur', 1), ('squirtle', 1), ('thrilling', 1), ('omelettes', 1), ('inherited?', 1), ('(how', 1), ('it)', 1), ("parent's", 1), ('electrocuted', 1), ('impinging', 1), ('industry-leading', 1), ('abuja', 1), ('bicubic', 1), ('spenic', 1), ('ex-convicts', 1), ('electroforming', 1), ('buttress?', 1), ('sparely', 1), ('diabetics?', 1), ('448', 1), ('mooring', 1), ('250k', 1), ('exercise/walking', 1), ('pulmonologist?', 1), ('tympanitis', 1), ('rheostat?', 1), ('nauseousness', 1), ('meggitt', 1), ('f81', 1), ('intergenic', 1), ('detasseling', 1), ('julington', 1), ('ciss', 1), ('fantastical', 1), ('filezilla', 1), ('clarisse.', 1), ('nephridia?', 1), ('yowie', 1)]

# %% [markdown]
# # 3. Evaluation Metrics & Supporting Functions

# %%
def query_sampler(df, percentage_of_samples = 0.9):
    """ 
    This function creates a sample set of queries from the orignal dataset
    
    Args:
        df (dataframe) -> The original dataframe
        percentage_of_samples (float) -> Between 0 and 1
        
    Returns:
        Sampled set of queries.
    
    """
    l = len(df)
    number_of_samples = int(l*percentage_of_samples)
    print("Number of instances being sampled is", number_of_samples)
    randomList = random.sample(range(0, l), number_of_samples)
    return(df.iloc[randomList])

# %%
def break_the_query(query_string):
    """
    This function breaks the query down on character level.
    
    Args:
        query_string(str) -> Original query string
        
    Returns:
        list_of_strings(iterable) -> A list of multiple sub-strings made from the query
    """
    list_of_strings = []
    l = len(query_string)
    for i in range (1, l-1):
        s = query_string[:i]
        list_of_strings.append(s)
    return list_of_strings

# %%
def train_test_split(df, train_percentage = 0.9):
    """ 
    This function creates a sample set of queries from the orignal dataset
    
    Args:
        df (dataframe) -> The original dataframe
        train_percentage (float) -> Represents the percentage of training examples. Between 0 and 1
        
    Returns:
        Training and testing data
    
    """
    l = len(df)
    number_of_training_samples = int(l*train_percentage)
    print("Number of instances being sampled for training data is", number_of_training_samples)
    train_List = random.sample(range(0, l), number_of_training_samples)
    test_List = []
    for i in range(l):
        if i not in train_List:
            test_List.append(i)
    return(df.iloc[train_List], df.iloc[test_List])

# %%
def distance_score(str1, str2):
    """
    This function calculates the Levenshtein distance between the two strings. Will use the library 'editdistance' for this task.
    
    Args:
        str1(string) -> String 1
        str2(string) -> String 2
        
    Returns:
        d (float) -> Represents the leveshtein distance between the two strings
    """
    d = editdistance.eval(str1, str2)
    return d

def best_distance_on_query(model, query_string):
    """
    This function returns the best distance score from all the suggestions made for a query.
    
    Args:
        model (object) -> Trained model object 
        query_string (string) -> The query string
        
    Returns:
        Best Levenshtein distance score of all the suggestions made by the model.
    """
    query_suggestions = model_1.getAutoSuggestions(query_string)
    least_distance = len(query_string) * 5
    for query_suggestion in query_suggestions:
        distance_measure = distance_score(query_suggestion, query_string)
        if distance_measure < least_distance:
            least_distance = distance_measure
    return least_distance

# %% [markdown]
# # 4. AutoSuggest Methods

# %% [markdown]
# ## Part 1: Dictionary Based Approach

# %% [markdown]
# #### Preparing Data
# Ideally the dictionary-based approach (without analyzers) shouldn't include words in the build dictionary, but I am gonna try it out as well.
# So, the data would be prepared for TRIE in two batches:
# 1. Simple queries data.
# 2. Simple queries data, along with all the words used in that queries data.

# %%
# This cell contains the point 1 of the two data forms described above.

#First I am gonna create a sample of ~36000 queries
queries_df_1 = query_sampler(queries_df, percentage_of_samples = 0.1)

# Next up, I'll remove the qid from the index
queries_df_1.reset_index(drop = True, inplace = True)

# Next I'll divide the queries data into train and test set. With 95% training data
train_queries_df_1, test_queries_df_1 = train_test_split(queries_df_1, train_percentage = 0.95)
train_queries_data_1 = train_queries_df_1['query'].values
test_queries_data_1 = test_queries_df_1['query'].values
print(train_queries_data_1)
print(len(train_queries_data_1))
#print(queries_data_1)
#print(len(queries_data_1))
# Out:
# Number of instances being sampled is 36701
# Number of instances being sampled for training data is 34865
# ['bone spicule definition' 'what language did the olmec speak'
#  'what are the biological views for depression' ...
#  'what year did kenneth hagin sr die' 'who plays lucien carr'
#  'who makes the disney princess and me dolls']
# 34865

# %%
# This cell contains data created by definition of point 2 of the two data forms described above.

#First I am gonna create a sample of ~36000 queries
queries_df_2 = query_sampler(queries_df, percentage_of_samples = 0.1)

# Next up, I'll remove the qid from the index
queries_df_2.reset_index(drop = True, inplace = True)

# Next up I am gonna add all the words in these queries seperately as well
sentences = queries_df_2['query'].values
tokens = []
for sentence in tqdm(sentences):
    for word in sentence.split(' '):
        # I will also have to remove the special characters from the words before putting them into the vocab. I will not remove numerics because many search queries might require numbers like WC20 or XL5 etc
        token = ""
        for character in word:
            if character.isalnum():
                token += character
        tokens.append(token)
vocab = list(set(tokens))
for word in vocab:
    queries_df_2 = queries_df_2.append({'query' : word}, ignore_index=True)
    
display(queries_df_2.tail(10))
display(len(queries_df_2))

# Next I'll divide the queries data into train and test set. With 95% training data
train_queries_df_2, test_queries_df_2 = train_test_split(queries_df_2, train_percentage = 0.95)
train_queries_data_2 = train_queries_df_2['query'].values
test_queries_data_2 = test_queries_df_2['query'].values
# Out:
#  19%|█▉        | 7019/36701 [00:00<00:00, 70181.70it/s]
# Number of instances being sampled is 36701
# 100%|██████████| 36701/36701 [00:00<00:00, 69159.13it/s]
#             query
# 62254  suppressor
# 62255   delicious
# 62256   testicles
# 62257   witnesses
# 62258       canon
# 62259     recieve
# 62260      welder
# 62261     pillars
# 62262         brb
# 62263     whiskey
# 62264
# Number of instances being sampled for training data is 59150

# %% [markdown]
# #### Model Creation: TRIE

# %%
class TrieNode(): 
    def __init__(self): 
          
        # Initialising one node for trie 
        self.children = {} 
        self.last = False
  

class Trie(): 
    def __init__(self): 
          
        # Initialising the trie structure. 
        self.root = TrieNode() 
        self.word_list = []
        self.count = 0
  
    def formTrie(self, keys): 
          
        # Forms a trie structure with the given set of strings 
        # if it does not exists already else it merges the key 
        # into it by extending the structure as required 
        for key in keys: 
            self.insert(key) # inserting one key to the trie. 
  
    def insert(self, key): 
          
        # Inserts a key into trie if it does not exist already. 
        # And if the key is a prefix of the trie node, just  
        # marks it as leaf node. 
        node = self.root 
  
        for a in list(key): 
            if not node.children.get(a): 
                node.children[a] = TrieNode() 
  
            node = node.children[a] 
  
        node.last = True
  
    def search(self, key): 
          
        # Searches the given key in trie for a full match 
        # and returns True on success else returns False. 
        node = self.root 
        found = True
  
        for a in list(key): 
            if not node.children.get(a): 
                found = False
                break
  
            node = node.children[a] 
  
        return node and node.last and found 
  
    def suggestionsRec(self, node, word): 
          
        # Method to recursively traverse the trie 
        # and return a whole word.  
        if node.last: 
            self.word_list.append(word) 
  
        for a,n in node.children.items(): 
            self.suggestionsRec(n, word + a)
            
    def limitedSuggestionsRec(self, node, word, no_of_suggestions): 
          
        # Method to recursively traverse the trie 
        # and return a whole word. But limit the number of routes ventured to no_of_suggestions
        if node.last:
            self.count = self.count + 1
            if self.count <= no_of_suggestions:
                self.word_list.append(word)

        for a,n in node.children.items():
            self.suggestionsRec(n, word + a) 
            
    
    def printAutoSuggestions(self, key, no_of_suggestions = 0): 
        # Returns all the words in the trie whose common 
        # prefix is the given key thus listing out all  
        # the suggestions for autocomplete. 
        node = self.root 
        not_found = False
        temp_word = '' 
        print('This function was called')
        characters = list(key)
        for a in characters:
            if not node.children.get(a): 
                not_found = True
                break
  
            temp_word += a 
            node = node.children[a] 
  
        if not_found: 
            return 0
        elif node.last and not node.children: 
            return -1
  
        if no_of_suggestions>0:
            self.count = 0
            self.limitedSuggestionsRec(node, temp_word, no_of_suggestions)
        else:
            self.suggestionsRec(node, temp_word)
  
        for s in self.word_list: 
            print(s) 
        return 1
    
    def getAutoSuggestions(self, key, no_of_suggestions = 0): 
          
        # Returns all the words in the trie whose common 
        # prefix is the given key thus listing out all  
        # the suggestions for autocomplete. 
        node = self.root 
        not_found = False
        temp_word = '' 
  
        characters = list(key)
        for a in characters:
            if not node.children.get(a): 
                not_found = True
                break
  
            temp_word += a 
            node = node.children[a] 
  
        if not_found: 
            return 0
        elif node.last and not node.children: 
            return -1
        
        if no_of_suggestions>0:
            self.count = 0
            self.limitedSuggestionsRec(node, temp_word, no_of_suggestions)
        else:
            self.suggestionsRec(node, temp_word)
   
        return self.word_list

# %% [markdown]
# #### Model Training
# We are gonna create two TRIE structures (one for each kind of data)

# %%
model_1 = Trie()
model_1.formTrie(train_queries_data_1)

# %%
model_2 = Trie()
model_2.formTrie(train_queries_data_2)

# %% [markdown]
# #### Model Testing
# We are gonna test each of the two models trained above using 3 metrics of evaluation:
# 1. Intuition Based (Will analyze the relevance of the search suggestions manually)
# 2. Distance Based (Will produce the overall score of test set using Levenshtein Distance)
# 3. Relevance Based (Will use semantic textual similarity to determine relevance of each of the suggestions).

# %% [markdown]
# ##### Model 1:

# %%
# I am first gonna define the three strings I'll be using for Intuition based testing
string1 = 'What building method might use a balloon frame?'
string2 = 'What is causing rash on arms'
string3 = 'What causes your glands on the top of your throat to swell'

# Next up, I am gonna create a list of sub strings from these queries
list_string1 = break_the_query(string1)
list_string2 = break_the_query(string2)
list_string3 = break_the_query(string3)

# Now, I'll print the query results after each new character being typed in
comp = model_1.printAutoSuggestions(string1) 
if comp == -1: 
    print("No other strings found with this prefix\n") 
elif comp == 0: 
    print("No string found with this prefix\n") 
break
# Out:
#   File "<ipython-input-36-6f9c335eaba9>", line 24
# SyntaxError: 'break' outside loop

# %% [markdown]
# ## Part 2: Analyzer Based Approach

# %% [markdown]
# ## Part 3: Content Based Approach
